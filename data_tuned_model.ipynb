# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('cleaned_data.csv')

# %%
df = data.copy()

# %%
df.head()
# Out:
#    Bathrooms  Bedrooms  Coverage  Domestic Rooms  Erf Size  Family/TV Room  \
# 0        2.0       3.0       NaN             NaN       NaN             3.0
# 1        3.0       3.0       NaN             NaN       NaN             NaN
# 2        1.5       1.0       NaN             NaN       NaN             NaN
# 3        2.0       3.0       NaN             NaN     400.0             NaN
# 4        2.0       3.0       NaN             NaN       NaN             NaN
#
#    Floor Size  Garage  Levies  Nearby Public Transport  ...  Wall  Window  \
# 0       133.0     1.0  1800.0                      NaN  ...   NaN     NaN
# 1       127.0     NaN  4055.0                      NaN  ...   NaN     NaN
# 2        71.0     NaN  4500.0                      3.0  ...   NaN     NaN
# 3       140.0     2.0  1050.0                      NaN  ...   NaN     NaN
# 4        84.0     NaN  1878.0                      NaN  ...   NaN     NaN
#
#             City      Price       Province            Suburbaine  \
# 0     roodepoort  1395000.0        gauteng      weltevreden-park
# 1       umhlanga  4950000.0  kwazulu-natal       sibaya-precinct
# 2        sandton  4999000.0        gauteng       sandton-central
# 3  somerset-west  1650000.0   western-cape       sir-lowrys-pass
# 4   jeffreys-bay  1295000.0   eastern-cape  jeffreys-bay-central
#
#    Dining Rooms Garden Kitchens  Lounges
# 0           1.0    1.0      1.0      NaN
# 1           1.0    1.0      1.0      1.0
# 2           NaN    NaN      1.0      1.0
# 3           NaN    NaN      NaN      1.0
# 4           NaN    NaN      1.0      1.0
#
# [5 rows x 34 columns]

# %%
df.var()
# Out:
# <ipython-input-331-28ded241fd7c>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# Bathrooms                  3.331585e+00
# Bedrooms                   4.227676e+00
# Coverage                   6.767420e+02
# Domestic Rooms             1.773572e-01
# Erf Size                   5.955274e+19
# Family/TV Room             1.549131e+00
# Floor Size                 3.889286e+07
# Garage                     1.157520e+00
# Levies                     1.732245e+08
# Nearby Public Transport    5.287214e-01
# No Transfer Duty           4.752917e-02
# Office                     5.596186e-02
# Parking                    3.343099e+00
# Pets Allowed               2.359465e-01
# Price per m²               7.172421e+08
# Rates and Taxes            1.261887e+10
# Reception Rooms            1.652808e+00
# Special Features           7.730229e-01
# Standalone Building        2.089021e-01
# Temperature Control        9.622619e-02
# Price                      1.000787e+13
# Dining Rooms               3.719923e-02
# Garden                     8.784259e-05
# Kitchens                   4.255392e-04
# Lounges                    3.259269e-02
# dtype: float64

# %% [markdown]
# # PRE-PROCESSING

# %%
# transform True to 1 and False to 0
boolean_features = ["No Transfer Duty", "Office","Pets Allowed", "Standalone Building"]
def process_boolean_features(value):
    if value==True:
        return 1
    else:
        return 0

# %%
for col in boolean_features:
    df[col] = df[col].map(process_boolean_features)

# %%
for col in df.columns:
    print(col, ">>" , df[col].unique())
    print("------------\n")
# Out:
# Bathrooms >> [ 2.   3.   1.5  2.5  5.   1.   nan  4.   3.5  4.5  6.   7.   8.   5.5
#  11.   6.5 10.   8.5  9.  10.5 18.  16.  22.  14.  24.  12.  13.  30.
#  15.  20.   7.5 34.   9.5 17.  12.5 25.   0.5 19.  52.  26.  15.5 23.
#  50.  35.  54.  53. ]
# ------------
#
# Bedrooms >> [ 3.   1.   5.   2.   4.   nan  6.   7.   8.   0.5 11.   1.5 13.   9.
#   2.5 10.   7.5 18.  16.   3.5 14.  12.  20.  36.  21.  15.  30.  17.
#   4.5 55.  19.  28.  29.  24.  34.  50.  22.  42.  49.  32.  52.  26.
#  23.  27.  54.  25.  82. ]
# ------------
#
# Coverage >> [ nan  27.  25.  32.  28.  35.  19.  10.  71.  48.  36.  38.  31.  29.
#   61.  47.  50.  45.  23.  43.  24.  53.  73.  44.  22. 100.  18.  16.
#   11.   1.  69.  21.  46.  59.  30.  33.  52.   7.  79.  37.  15.  12.
#   39.  84.  40.  62.  56.   5.  26.  13.  57.  41.  20.  65.  49.  72.
#   17.  66.  64.  74.   4.  42.  92.  78.  87.   3.  51.  86.  55.  82.
#    9.  97.  81.  80.   2.  54.  85.  58.  98.  70.  60.  68.  34.  63.
#   67.  99.  14.  96.   8.   6.  94.  77.  88.  76.  93.  75.  95.  91.
#   90.  83.]
# ------------
#
# Domestic Rooms >> [nan  1.  2.  4.  3.  6.  8. 14.  5.]
# ------------
#
# Erf Size >> [    nan    400.    436. ...   4922. 272700.  15614.]
# ------------
#
# Family/TV Room >> [ 3. nan  1.  2.  5.  4.  6.  7.  8. 10. 11.]
# ------------
#
# Floor Size >> [1.3300e+02 1.2700e+02 7.1000e+01 1.4000e+02 8.4000e+01 1.2100e+02
#  1.3200e+02        nan 5.0000e+01 1.0000e+00 1.1600e+02 6.5000e+01
#  5.6000e+01 5.3000e+01 1.2000e+02 3.5600e+02 7.7000e+01 1.6400e+02
#  8.8000e+01 1.5900e+02 7.8000e+01 1.2500e+02 1.6600e+02 1.1700e+02
#  1.0400e+02 7.0000e+01 4.1000e+01 4.2700e+02 4.4100e+02 1.5400e+02
#  5.7200e+02 4.6000e+02 2.2000e+02 8.6000e+01 2.7000e+02 8.0000e+01
#  7.6000e+01 2.8000e+01 7.1400e+02 3.9000e+02 1.8000e+02 1.0800e+02
#  2.5800e+02 5.8000e+01 1.2400e+02 1.6000e+02 8.9000e+01 3.2000e+01
#  1.1900e+02 4.2000e+01 6.2000e+01 1.9300e+02 2.8000e+02 3.7000e+02
#  9.0000e+01 1.7700e+02 3.0800e+02 8.5000e+01 6.6000e+01 3.7800e+02
#  1.1000e+02 2.3900e+02 7.2000e+01 2.6200e+02 9.5000e+01 1.5200e+02
#  7.3000e+01 4.4000e+01 3.5000e+02 2.5500e+02 6.1000e+01 2.0000e+02
#  1.3900e+02 1.4900e+02 3.0700e+02 1.1200e+02 5.7000e+01 4.0000e+02
#  1.6900e+02 2.7400e+02 4.8000e+01 1.9000e+02 2.1000e+02 3.2000e+02
#  8.1000e+01 2.3000e+02 3.0000e+02 2.0900e+02 3.6800e+02 5.2000e+01
#  5.5200e+02 2.5000e+02 3.8000e+02 3.6000e+02 1.9200e+02 5.9000e+01
#  1.8200e+02 5.5000e+02 6.4000e+01 1.7500e+02 1.4800e+02 6.0000e+01
#  2.4100e+02 3.4000e+02 1.7200e+02 8.7000e+01 1.1400e+02 7.0000e+02
#  5.1000e+01 2.0600e+02 6.9000e+01 1.3800e+02 1.0700e+02 5.6000e+02
#  1.6300e+02 9.9000e+01 5.0000e+02 1.1300e+02 8.3000e+01 9.6000e+01
#  1.8300e+02 2.8400e+02 9.3000e+01 1.6700e+02 1.7100e+02 5.5000e+01
#  2.9600e+02 1.1800e+02 1.8800e+02 4.9000e+02 8.5600e+02 2.2500e+02
#  1.0200e+02 9.9200e+02 2.7600e+02 4.9500e+02 4.3000e+01 2.6700e+02
#  3.1400e+02 1.0100e+02 2.2900e+02 9.2000e+01 1.8500e+02 2.5900e+02
#  7.3500e+02 4.5000e+01 2.0400e+02 1.0500e+02 9.8000e+01 5.1000e+02
#  7.5000e+02 3.6000e+01 4.0000e+01 1.2600e+02 2.4900e+02 9.7000e+01
#  7.5000e+01 3.9000e+01 1.3700e+02 2.6400e+02 5.3100e+02 1.0000e+02
#  1.5700e+02 2.4200e+02 1.7900e+02 1.4400e+02 3.1100e+02 1.1500e+02
#  6.7000e+01 3.3000e+01 8.2000e+01 7.4000e+01 6.3000e+01 1.3000e+02
#  2.0200e+02 2.9000e+01 9.1000e+01 2.8500e+02 2.1400e+02 3.5200e+02
#  1.8400e+02 2.4000e+02 3.2500e+02 1.3500e+02 4.9800e+02 6.0000e+02
#  2.0500e+02 2.1800e+02 5.4000e+01 2.6000e+02 4.6000e+01 1.2800e+02
#  1.0830e+03 2.9700e+02 4.0700e+02 3.8500e+02 4.5000e+02 1.1190e+03
#  4.7000e+01 2.3200e+02 2.2300e+02 1.9700e+02 2.1200e+02 5.3000e+02
#  2.0100e+02 1.9500e+02 1.6100e+02 1.5000e+02 1.7000e+02 3.0900e+02
#  3.8000e+01 3.3400e+02 2.4400e+02 1.0900e+02 8.0000e+02 2.1500e+02
#  1.7400e+03 3.9600e+02 1.2278e+04 1.8700e+02 1.5100e+02 1.6200e+02
#  6.7000e+02 2.4500e+02 2.1300e+02 1.0300e+02 1.1100e+02 5.2400e+02
#  1.6800e+02 3.1500e+02 7.2000e+02 6.6000e+02 3.7500e+02 9.4000e+01
#  1.6500e+02 2.7800e+02 7.3300e+02 3.4000e+01 3.1000e+02 1.4500e+02
#  4.4000e+02 2.3500e+02 3.6600e+02 3.0000e+01 2.8100e+02 7.6400e+02
#  9.9400e+02 1.4200e+02 6.8000e+01 7.8000e+02 4.7400e+02 2.6600e+02
#  2.9500e+02 3.8200e+02 1.4600e+02 6.7200e+02 7.9000e+01 2.4700e+02
#  1.5420e+03 3.2700e+02 2.9300e+02 1.3100e+02 1.0600e+02 6.2000e+02
#  4.3000e+02 8.1000e+02 2.6800e+02 3.1000e+01 2.7500e+02 3.7300e+02
#  1.2000e+03 4.2000e+02 3.4400e+02 3.8800e+02 4.2900e+02 1.4100e+02
#  6.8400e+02 2.3400e+02 1.5500e+02 9.0000e+02 3.2200e+02 3.3300e+02
#  1.0970e+03 2.7000e+01 1.3600e+02 1.2300e+02 3.3800e+02 1.5800e+02
#  1.3400e+02 1.7400e+02 1.9900e+02 1.7800e+02 1.5600e+02 2.2700e+02
#  1.9830e+03 5.4000e+02 1.2200e+02 1.2900e+02 4.8700e+02 4.8000e+02
#  4.0800e+02 2.1700e+02 5.7000e+02 3.7000e+01 4.0100e+02 5.1600e+02
#  3.2100e+02 3.0500e+02 5.7800e+02 1.9780e+03 2.7300e+02 8.7200e+02
#  4.1900e+02 4.4500e+02 1.0800e+03 5.1500e+02 2.9800e+02 1.7300e+02
#  1.8600e+02 5.2100e+02 1.0000e+03 2.5400e+02 4.3700e+02 3.1700e+02
#  1.0810e+03 3.7100e+02 2.1600e+02 5.4400e+02 5.4500e+02 1.7600e+02
#  1.8100e+02 2.0300e+02 2.9000e+02 2.3700e+02 5.2000e+02 5.0600e+02
#  2.2400e+02 4.3500e+02 4.9000e+01 2.5300e+02 3.5900e+02 5.7500e+02
#  3.1900e+02 4.4200e+02 3.6700e+02 2.5700e+02 3.2800e+02 3.5400e+02
#  6.5000e+02 2.8800e+02 4.9600e+02 6.1500e+02 4.9100e+02 3.8700e+02
#  3.5000e+01 4.0500e+02 3.8300e+02 3.5100e+02 4.0400e+02 1.4700e+02
#  2.4000e+01 4.8600e+02 2.7900e+02 7.6300e+02 6.4000e+02 3.1300e+02
#  3.3600e+02 5.0700e+02 2.3000e+01 4.1800e+02 1.9400e+02 2.7100e+02
#  4.3200e+02 5.8000e+02 4.4400e+02 8.8900e+02 3.5300e+02 5.4200e+02
#  6.2500e+02 4.5600e+02 5.1400e+02 2.3100e+02 4.0300e+02 3.5500e+02
#  2.6000e+01 3.6100e+02 1.4300e+02 6.1700e+02 5.9000e+02 2.0700e+02
#  2.5100e+02 4.8200e+02 1.9800e+02 7.6100e+02 8.5000e+02 2.7200e+02
#  6.1300e+02 6.1000e+02 6.7300e+02 9.3300e+02 4.4300e+02 2.5000e+03
#  7.1900e+02 2.6100e+02 4.7300e+02 1.9000e+03 2.2000e+01 7.1800e+02
#  2.2600e+02 3.9500e+02 2.6500e+02 2.1100e+02 2.9400e+02 3.3760e+03
#  1.6310e+03 3.4700e+02 4.7000e+02 3.0300e+02 1.4980e+03 3.4900e+02
#  1.3560e+03 3.1800e+02 3.3000e+02 3.9800e+02 4.9400e+02 4.7600e+02
#  5.1800e+02 4.1000e+02 7.9100e+02 5.0200e+02 7.2100e+02 3.7200e+02
#  2.8600e+02 4.7500e+02 4.1200e+02 5.3400e+02 3.3100e+02 4.6700e+02
#  3.5800e+02 1.9000e+01 4.2300e+02 2.4300e+02 4.2500e+02 2.1900e+02
#  3.0100e+02 7.5000e+05 3.2300e+02 1.9100e+02 5.9700e+02 4.3100e+02
#  2.5600e+02 3.8900e+02 1.0340e+03 2.2800e+02 1.5300e+02 3.6300e+02
#  1.2080e+03 3.2400e+02 1.7000e+01 7.4200e+02 9.8000e+02 5.8200e+02
#  4.2200e+02 1.0090e+03 5.3500e+02 6.8000e+02 2.5000e+01 2.1000e+01
#  1.3520e+03 6.7500e+02 5.5900e+02 1.8000e+03 1.3000e+01 2.2200e+02
#  4.9300e+02 8.2000e+02 1.4820e+03 1.4000e+03 9.2400e+02 7.4000e+02
#  7.3000e+02 5.5500e+02 5.9800e+02 4.0600e+02 2.3300e+02 3.4100e+02
#  7.6000e+02 9.9800e+02 4.5400e+02 4.2400e+02 5.8300e+02 2.9200e+02
#  7.1600e+02 8.3200e+02 5.0400e+02 1.3250e+03 1.8900e+02 2.0000e+01
#  1.9600e+02 2.9100e+02 3.6400e+02 3.3500e+02 2.2100e+02 3.9840e+03
#  3.0200e+02 3.1600e+02 3.4600e+02 1.2770e+03 6.4500e+02 3.9100e+02
#  6.8800e+02 4.9700e+02 1.0870e+03 1.3820e+03 3.7900e+02 7.2700e+02
#  3.4200e+02 3.3450e+03 8.8000e+02 5.6800e+02 1.1970e+03 4.4600e+02
#  5.1900e+02 3.0600e+02 5.6700e+02 3.9900e+02 9.2500e+02 6.4100e+02
#  4.6500e+02 2.7000e+03 3.8160e+03 3.7400e+02 4.8500e+02 1.3500e+03
#  1.0410e+03 2.8200e+02 4.1300e+02 9.7220e+03 1.5240e+03 9.2600e+02
#  5.0900e+02 4.1100e+02 3.9400e+02 6.0600e+02 4.5100e+02 8.0400e+02
#  4.2100e+02 5.8600e+02 1.2000e+01 4.4800e+02 6.0900e+02 9.5300e+02
#  2.9700e+03 1.1320e+03 5.9600e+02 3.6500e+02 2.8300e+02 5.8800e+02
#  2.3600e+02 3.2900e+02 3.0400e+02 5.1200e+02 4.1500e+02 5.3700e+02
#  1.2039e+04 3.8400e+02 3.5700e+02 1.1760e+03 9.0900e+02 4.3300e+02
#  1.2870e+03 3.9700e+02 8.7000e+02 2.4800e+02 6.3500e+02 7.1700e+02
#  8.3700e+02 1.0440e+03 3.9300e+02 2.2150e+04 3.9200e+02 3.6200e+02
#  1.6000e+03 2.6300e+02 7.0700e+02 6.6400e+02 6.5100e+02 1.0070e+03
#  4.5500e+02 9.1600e+02 5.6900e+02 1.1000e+03 6.1800e+02 3.1200e+02
#  7.5400e+02 4.1400e+02 2.0520e+03 3.3900e+02 2.8700e+02 7.7000e+02
#  9.3600e+02 5.2800e+02 6.0300e+02 4.6600e+02 7.2300e+02 2.8900e+02
#  2.8120e+03 5.9100e+02 5.0800e+02 4.8800e+02 7.9300e+02 1.8000e+01
#  1.3000e+03 6.9800e+02 3.2600e+02 7.1100e+02 3.7600e+02 5.5800e+02
#  8.1600e+02 2.3040e+03 5.1300e+02 4.2600e+02 4.7800e+02 9.3000e+02
#  3.4300e+02 8.2900e+02 6.5300e+02 5.0500e+02 8.6300e+02 5.8400e+02
#  4.5700e+02 1.6000e+01 2.0800e+02 9.4700e+02 3.3200e+02 3.7200e+03
#  1.6400e+03 5.9200e+02 2.7550e+03 7.9000e+02 9.4400e+02 2.9900e+02
#  1.3700e+03 1.0960e+03 5.1100e+02 1.4940e+03 1.1900e+03 1.5030e+03
#  1.5110e+03 1.2020e+03 1.0900e+03 6.2300e+02 6.9600e+02 2.3800e+02
#  1.2400e+03 9.6000e+02 9.5600e+02 6.9000e+02 2.4600e+02 4.7900e+02
#  4.6100e+02 9.5000e+02 2.2840e+03 7.5100e+02 8.0600e+02 4.3400e+02
#  4.2800e+02 8.2200e+02 9.2000e+02 4.6300e+02 2.6900e+02 8.6000e+02
#  2.5200e+02 5.5300e+02 4.0200e+02 1.3580e+03 5.3600e+02 6.3000e+02
#  5.0100e+02 5.3200e+02 6.8300e+02 6.3900e+02 8.2600e+02 8.6500e+02
#  1.0700e+03 5.6500e+02 9.9000e+02 5.7700e+02 2.4070e+03 1.2800e+03
#  1.0120e+03 2.1413e+04 1.1710e+03 8.5100e+02 2.8000e+03 4.6400e+02
#  4.4900e+02 6.1100e+02 4.5800e+02 4.0470e+03 9.0500e+02 3.5750e+03
#  1.9790e+03 3.7700e+02 3.4500e+02 8.5700e+02 5.2600e+02 1.2500e+03
#  7.1500e+02 1.7600e+03 1.4060e+03 1.0500e+03 1.1087e+04 6.9900e+02
#  2.0000e+03 4.7200e+02 9.4900e+02 8.4000e+02 4.4700e+02 4.3900e+02
#  3.8100e+02 5.6100e+02 4.5200e+02 1.0882e+04 1.1010e+03 6.2900e+02
#  7.0800e+02 1.0560e+03 2.0000e+00 6.3100e+02 8.9000e+02 9.7500e+02
#  1.5000e+03 5.0000e+03 5.4600e+02 1.7840e+03 5.2900e+02 1.6470e+03
#  2.0950e+03 4.7700e+02 7.5000e+03 5.2500e+02 6.1600e+02 7.3800e+02
#  1.4600e+03 1.6050e+03 4.7100e+02 1.4560e+03 6.3800e+02 8.9700e+02
#  1.2500e+04 5.9400e+02 1.7100e+03 9.9300e+02 1.8810e+03 3.8600e+02
#  6.7400e+02 1.0240e+03 6.9700e+02 5.4800e+02 6.0200e+02 3.4730e+03
#  1.0220e+03 6.2200e+02 9.9100e+02 5.2700e+02 4.8300e+02 4.0900e+02
#  2.0320e+03 6.3200e+02 1.2930e+03 4.7070e+03 9.4000e+02 6.0400e+02
#  6.5600e+02 1.0450e+03 9.1700e+02 8.9600e+02 7.1200e+02 4.3600e+02
#  4.5900e+02 7.9200e+02 3.4800e+02 1.4900e+03 4.3800e+02 8.8500e+02
#  6.2700e+02 1.4920e+03 6.5200e+02 7.5700e+02 1.1500e+03 9.9500e+02
#  1.1810e+03 6.6100e+02 2.4950e+03 1.1930e+03 6.6900e+02 2.9580e+03
#  8.8200e+02 1.2558e+04 9.8800e+02 1.2240e+03 1.0930e+03 9.4600e+02
#  1.0350e+03 8.6600e+02 8.3000e+02 9.5200e+02 6.0800e+02 8.7500e+02
#  5.6600e+02 7.2600e+02 5.3900e+02 8.7700e+02 1.4280e+03 5.3800e+02
#  8.8800e+02 6.8600e+02 4.9200e+02 1.0000e+01 1.0000e+05 7.2500e+02
#  6.0700e+02 1.1730e+03 9.9900e+02 6.1900e+02 6.0500e+02 6.7800e+02
#  1.5890e+03 6.3600e+02 1.1960e+03 8.9500e+02 1.2440e+03 9.6800e+02
#  1.0460e+03 6.5500e+02 7.0200e+02 2.0890e+03 6.5400e+02 8.1580e+03
#  7.2400e+02 1.8710e+03 7.9500e+02 6.7100e+02 1.6900e+03 3.0000e+03
#  4.1700e+02 7.4800e+02 6.3400e+02 5.8700e+02 7.3200e+02 7.4400e+02
#  1.0600e+03 1.4930e+03 9.3500e+02 3.3700e+02 2.1500e+03 8.5500e+02
#  1.0010e+03 7.6700e+02 1.2100e+03 1.0710e+03 1.5590e+03 1.4170e+03
#  7.3400e+02 2.0510e+03 8.5000e+03 6.6200e+02 1.2840e+03 1.1800e+03
#  1.1040e+03 3.8850e+03 1.1160e+03 7.7200e+02 4.5300e+02 8.7300e+02
#  2.0300e+03 6.3300e+02 5.4280e+03 4.0000e+00 8.3500e+02 1.9090e+03
#  6.4700e+02 5.3300e+02 1.4370e+03 2.7700e+02 6.6300e+02 2.2640e+03
#  1.0000e+04 5.8500e+02 2.3500e+03 1.6100e+03 1.0610e+03 1.2010e+03
#  4.6800e+02 1.7000e+03 1.5290e+03 8.8100e+02 6.3170e+03 5.5600e+02
#  4.8900e+02 4.1600e+02 4.2877e+04 1.1260e+03 1.2390e+03 2.0650e+03
#  7.9400e+02 3.7850e+04 5.2200e+02 7.7710e+03 5.9500e+02 6.8200e+02
#  9.0000e+00 1.6920e+03 8.5570e+03 7.3600e+02 8.4600e+02 2.2375e+04
#  4.6200e+02 1.3460e+03 7.5300e+02 2.4000e+05 9.6300e+02 1.0820e+03
#  1.5860e+03 1.7390e+03]
# ------------
#
# Garage >> [ 1.   nan  2.   3.   4.   5.  10.   6.  15.   7.   3.5  2.5  8.  11.
#   9.   1.5  0.5 12.  20.  23.  16.  29.   5.5]
# ------------
#
# Levies >> [1800. 4055. 4500. ... 1692. 2079. 2048.]
# ------------
#
# Nearby Public Transport >> [nan  3.  2.  1.]
# ------------
#
# No Transfer Duty >> [0 1]
# ------------
#
# Office >> [0 1]
# ------------
#
# Parking >> [ 1.  2.  0.  4.  5.  8.  3.  6. 12. 20.  7. 10. 11. 16. 27. 15. 50.  9.
#  13. 14. 25. 22. 36. 30. 17. 24. 29. 21. 32. 18. 94.]
# ------------
#
# Pets Allowed >> [1 0]
# ------------
#
# Price per m² >> [   nan 38976. 70408. ... 18382. 14384.  5905.]
# ------------
#
# Rates and Taxes >> [ 600. 3294. 2500. ... 2157. 3372. 1211.]
# ------------
#
# Reception Rooms >> [nan  2.  3.  1.  5.  6.  4.  8. 46. 10.  7.  9. 12. 20.]
# ------------
#
# Roof >> [nan 'Tile' 'Flat Roof' 'Fibre Cement' 'Tile, Concrete'
#  'Slate, Waterproofing, Insulation' 'Iron, Insulation' 'Iron'
#  'Tile, Insulation' 'Asbestos' 'Tile, Slate, Insulation' 'Concrete'
#  'Thatch' 'Flat Roof, Iron' 'Iron, Zinc' 'Aluminium' 'Insulation'
#  'Flat Roof, Aluminium' 'Zinc' 'Slate' 'Tile, Waterproofing'
#  'Flat Roof, Insulation' 'Tile, Thatch, Fibreglass' 'Tile, Zinc'
#  'Tile, Concrete, Insulation' 'Tile, Thatch' 'Tile, Slate'
#  'Galvanised Steel' 'Tile, Shingles' 'Concrete, Zinc'
#  'Asbestos, Concrete, Zinc' 'Flat Roof, Tile, Concrete'
#  'Thatch, Insulation' 'Iron, Asbestos' 'Tile, Asbestos' 'Waterproofing'
#  'Iron, Slate' 'Flat Roof, Tile, Concrete, Insulation' 'Flat Roof, Tile'
#  'Iron, Tile, Concrete, Insulation' 'Flat Roof, Concrete'
#  'Iron, Tile, Insulation' 'Tile, Slate, Waterproofing' 'Iron, Tile'
#  'Aluminium, Waterproofing, Zinc' 'Flat Roof, Zinc' 'Brown Built'
#  'Shingles, Fibre Cement' 'Flat Roof, Brown Built' 'Iron, Thatch'
#  'Slate, Asbestos' 'Flat Roof, Concrete, Aluminium'
#  'Flat Roof, Iron, Insulation' 'Asbestos, Concrete' 'Tile, Glass Dome'
#  'Aluminium, Zinc' 'Waterproofing, Zinc'
#  'Flat Roof, Asbestos, Concrete, Zinc' 'Shingles' 'Tile, Aluminium'
#  'Iron, Tile, Concrete' 'Brown Built, Waterproofing, Insulation'
#  'Flat Roof, Iron, Tile, Thatch, Zinc' 'Flat Roof, Galvanised Steel'
#  'Tile, Waterproofing, Insulation']
# ------------
#
# Security >> [nan '1' 'Security Gate, Alarm System, Intercom, Electric fencing' ...
#  'Electric Gate, Security Gate, 24 Hour Response, 24 Hour Access, Guard House, Boomed Area, Safe'
#  'Totally Fenced, Electric Garage, Security Gate, 24 Hour Response, Burglar Bars, Electric fencing, Boomed Area, Safe'
#  'Security Gate, 24 Hour Response, 24 Hour Access, Guard House, Guard, Perimeter Wall']
# ------------
#
# Special Features >> [ 0  3  1  4  6  5  2  8  9  7 11 10 12 13]
# ------------
#
# Standalone Building >> [0 1]
# ------------
#
# Style >> [nan 'Open Plan, Classical' 'Conventional' 'Contemporary, Modern' 'Modern'
#  'Open Plan' 'Open Plan, Traditional' 'Victorian'
#  'Conventional, Modern, Open Plan' 'Modern, Open Plan'
#  'Conventional, Contemporary' 'Split Level' 'Contemporary' 'Traditional'
#  'Conventional, Open Plan' 'Modern, Open Plan, Architect-designed'
#  'Mediterranean' 'Tuscan' 'Contemporary, Architect-designed'
#  'Conventional, Architect-designed' 'Modern, Cape Dutch'
#  'Tuscan, Architect-designed' 'Architect-designed'
#  'Contemporary, Open Plan, Architect-designed' 'Colonial, Classical'
#  'Modern, Split Level'
#  'Modern, Open Plan, Ultra Modern, Architect-designed' 'Cape Dutch'
#  'Modern, A-frame, Open Plan' 'Split Level, Open Plan' 'Cottage'
#  'Modern, Open Plan, Traditional, Architect-designed' 'Classical'
#  'Modern, Open Plan, Traditional' 'Contemporary, Cottage, Open Plan'
#  'Modern, Tuscan, Ultra Modern, Classical, Architect-designed'
#  'Open Plan, Traditional, Architect-designed'
#  'Open Plan, Architect-designed' 'Ultra Modern' 'Colonial'
#  'Conventional, Modern' 'Balinese' 'A-frame'
#  'Contemporary, Modern, Open Plan'
#  'Open Plan, Ultra Modern, Architect-designed'
#  'Split Level, Open Plan, Ultra Modern, Architect-designed'
#  'Modern, Mediterranean, Tuscan' 'Modern, Architect-designed'
#  'Conventional, Colonial' 'Modern, Open Plan, Ultra Modern'
#  'Mediterranean, Architect-designed' 'Modern, Ultra Modern'
#  'Tuscan, Open Plan' 'Conventional, A-frame'
#  'Mediterranean, Open Plan, Architect-designed'
#  'Contemporary, Ultra Modern' 'Contemporary, Open Plan'
#  'Conventional, Tuscan, Open Plan' 'Colonial, Open Plan'
#  'Open Plan, Ultra Modern' 'Open Plan, Classical, Traditional'
#  'A-frame, Open Plan'
#  'Contemporary, Open Plan, Ultra Modern, Architect-designed'
#  'Modern, Spanish, Open Plan' 'Cottage, Classical' 'Modern, Mediterranean'
#  'Ultra Modern, Architect-designed'
#  'Contemporary, Modern, Open Plan, Architect-designed'
#  'Contemporary, Ultra Modern, Architect-designed'
#  'Contemporary, Modern, Architect-designed'
#  'Conventional, Contemporary, Modern' 'Modern, Open Plan, Classical'
#  'Contemporary, Modern, Open Plan, Ultra Modern, Architect-designed'
#  'Modern, A-frame' 'Conventional, Split Level, Open Plan'
#  'Conventional, Traditional' 'Classical, Architect-designed'
#  'Contemporary, Modern, Traditional'
#  'Conventional, Modern, Architect-designed'
#  'Tuscan, Open Plan, Ultra Modern, Architect-designed'
#  'Conventional, Contemporary, Architect-designed'
#  'Contemporary, Cottage, Traditional'
#  'Conventional, Modern, A-frame, Tuscan, Open Plan' 'Cottage, Open Plan'
#  'Modern, Tuscan' 'Modern, Split Level, Open Plan' 'Provencal'
#  'Tuscan, Open Plan, Architect-designed'
#  'Conventional, Open Plan, Ultra Modern' 'Tuscan, Ultra Modern'
#  'Conventional, Split Level'
#  'Split Level, Tuscan, Open Plan, Architect-designed'
#  'Cottage, Colonial, Split Level, Open Plan, Ultra Modern'
#  'Modern, Tuscan, Open Plan' 'Conventional, Cottage' 'Modern, Colonial'
#  'Contemporary, Modern, Ultra Modern, Architect-designed'
#  'A-frame, Classical' 'Modern, Classical' 'Conventional, Ultra Modern'
#  'Conventional, Contemporary, Modern, Architect-designed' 'Spanish'
#  'Spanish, Split Level' 'Contemporary, A-frame'
#  'Contemporary, Modern, A-frame' 'Modern, Mediterranean, Open Plan'
#  'Conventional, Open Plan, Traditional' 'Classical, Traditional'
#  'Modern, Tuscan, Architect-designed' 'Open Plan, Provencal'
#  'Cottage, Spanish' 'Modern, Provencal' 'Cottage, Traditional'
#  'Modern, Traditional'
#  'Modern, Cape Dutch, Split Level, Open Plan, Provencal'
#  'Modern, Cottage, Split Level, Open Plan' 'Contemporary, Cottage'
#  'Contemporary, Modern, Split Level, Open Plan, Ultra Modern, Classical'
#  'Split Level, Tuscan' 'Contemporary, Open Plan, Classical'
#  'Contemporary, Open Plan, Traditional' 'Mediterranean, Split Level'
#  'A-frame, Tuscan' 'Tuscan, Traditional' 'Split Level, Architect-designed'
#  'Colonial, A-frame' 'Modern, Balinese' 'Contemporary, Split Level'
#  'Conventional, Modern, Split Level, Open Plan'
#  'Conventional, Cottage, Tuscan'
#  'Conventional, Modern, Classical, Architect-designed'
#  'Contemporary, Modern, A-frame, Tuscan'
#  'Conventional, Modern, Open Plan, Architect-designed'
#  'Cottage, Split Level' 'Modern, A-frame, Open Plan, Architect-designed'
#  'Contemporary, Spanish' 'Victorian, Classical'
#  'Open Plan, Balinese, Architect-designed'
#  'Conventional, A-frame, Split Level, Open Plan'
#  'Cottage, Open Plan, Traditional'
#  'Contemporary, Mediterranean, Open Plan' 'A-frame, Architect-designed'
#  'Open Plan, Balinese' 'Modern, Split Level, Architect-designed'
#  'Cape Dutch, Open Plan, Classical'
#  'Conventional, Contemporary, Modern, Open Plan'
#  'Modern, A-frame, Ultra Modern, Architect-designed'
#  'Conventional, Ultra Modern, Architect-designed'
#  'Mediterranean, Open Plan']
# ------------
#
# Temperature Control >> [0 1 2 3 4 5]
# ------------
#
# Type of Property >> ['Townhouse' 'Apartment / Flat' 'House' 'Commercial Property'
#  'Vacant Land / Plot' 'Industrial Property' 'Farm']
# ------------
#
# Wall >> [nan 'Face-brick' 'Brick' 'Plaster' 'Plaster, Concrete'
#  'Plaster, Face-brick' 'Brick, Plaster, Concrete'
#  'Plaster, Concrete, Wood, Iron' 'Brick, Plaster'
#  'Brick, Plaster, Concrete, Face-brick' 'Brick, Plaster, Face-brick'
#  'Concrete' 'Plaster, Concrete, Face-brick' 'Brick, Plaster, Stone'
#  'Brick, Glass' 'Plaster, Stone' 'Plaster, Stone, Face-brick'
#  'Wood, Face-brick' 'Concrete, Face-brick' 'Plaster, Wood'
#  'Brick, Concrete' 'Brick, Stone, Glass' 'Stone' 'Iron'
#  'Plaster, Concrete, Iron' 'Brick, Plaster, Concrete, Wood' 'Wood'
#  'Plaster, Iron' 'Brick, Wood' 'Brick, Face-brick'
#  'Plaster, Concrete, Wood' 'Plaster, Asbestos' 'Iron, Face-brick'
#  'Plaster, Wood, Stone, Face-brick' 'Brick, Plaster, Wood, Stone'
#  'Stone, Face-brick' 'Brick, Asbestos' 'Brick, Wood, Face-brick'
#  'Brick, Plaster, Concrete, Wood, Asbestos, Iron, Stone' 'Asbestos'
#  'Concrete, Iron' 'Brick, Stone' 'Brick, Plaster, Iron, Stone, Face-brick'
#  'Brick, Plaster, Wood, Iron, Stone, Glass' 'Plaster, Wood, Face-brick'
#  'Brick, Plaster, Stone, Face-brick' 'Concrete, Stone']
# ------------
#
# Window >> [nan 'Wood' 'Aluminium' 'Wood, Aluminium' 'Aluminium, Bay, Skylight'
#  'Steel ' 'Steel , Cottage' 'Cottage' 'Steel , Aluminium' 'Steel , Wood'
#  'Wood, Aluminium, Skylight' 'Steel , Aluminium, Cottage' 'Wood, Cottage'
#  'Skylight' 'Aluminium, Double Glazed'
#  'Aluminium, Double Glazed, Skylight' 'Aluminium, Bay'
#  'Steel , Wood, Aluminium' 'Wood, Aluminium, Cottage' 'Aluminium, Stained'
#  'Aluminium, Skylight' 'Wood, Bay' 'Wood, Dormer' 'Double Glazed'
#  'Wood, Double Glazed' 'Wood, Aluminium, Bay' 'Bay' 'Wood, Bay, Cottage'
#  'Wood, Lead, Stained, Bay' 'Aluminium, Cottage'
#  'Steel , Bay, Cottage, Skylight' 'Wood, Skylight']
# ------------
#
# City >> ['roodepoort' 'umhlanga' 'sandton' 'somerset-west' 'jeffreys-bay'
#  'cape-town' 'paarl' 'grahamstown' 'soshanguve' 'pretoria' 'blouberg'
#  'kraaifontein' 'stellenbosch' 'bloemfontein' 'polokwane' 'edenvale'
#  'vereeniging' 'durban' 'white-river' 'hartbeespoort' 'pietermaritzburg'
#  'hillcrest' 'simons-town' 'noordhoek' 'johannesburg' 'germiston'
#  'alberton' 'kempton-park' 'pringle-bay' 'midrand' 'gordons-bay'
#  'randburg' 'eersterivier' 'modimolle' 'brackenfell' 'port-elizabeth'
#  'mossel-bay' 'milnerton' 'durbanville' 'pinetown' 'witbank' 'port-alfred'
#  'ballito' 'knysna' 'krugersdorp' 'hout-bay' 'benoni' 'bredasdorp'
#  'plettenberg-bay' 'wellington' 'melkbosstrand' 'east-london'
#  'bronkhorstspruit' 'st-francis-bay' 'elands-bay' 'centurion'
#  'kuils-river' 'akasia' 'bellville' 'boksburg' 'bedfordview' 'randfontein'
#  'potchefstroom' 'george' 'stilbaai' 'parow' 'bettys-bay' 'nelspruit'
#  'tembisa' 'westville' 'fish-hoek' 'uitenhage' 'san-lameer' 'langebaan'
#  'hoedspruit' 'montagu' 'kleinmond' 'hermanus' 'hartenbos' 'mtwalume'
#  'kloof' 'franschhoek' 'richards-bay' 'strand' 'kingsburgh' 'gansbaai'
#  'mount-edgecombe' 'brits' 'caledon' 'durban-north' 'sasolburg'
#  'mitchells-plain' 'secunda' 'amanzimtoti' 'margate' 'rustenburg' 'welkom'
#  'vanderbijlpark' 'delmas' 'khayelitsha' 'velddrif' 'westonaria' 'nigel'
#  'soweto' 'stilfontein' 'komga' 'heidelberg' 'king-williams-town'
#  'port-edward' 'springs' 'parys' 'brakpan' 'yzerfontein' 'middelburg'
#  'kimberley' 'paul-roux' 'port-shepstone' 'bethlehem' 'evaton' 'underberg'
#  'lephalale' 'marloth-park' 'ladysmith' 'umdloti' 'newcastle' 'lydenburg'
#  'belfast' 'estcourt' 'saldanha' 'goodwood' 'klerksdorp' 'zinkwazi-beach'
#  'standerton' 'umkomaas' 'mookgopong' 'pennington' 'vaal-marina'
#  'kroonstad' 'sabie' 'verulam' 'wolmaransstad' 'empangeni' 'meyerton'
#  'upington' 'peddie' 'mtubatuba' 'brandfort' 'tzaneen' 'chatsworth'
#  'howick' 'humansdorp' 'despatch' 'fochville' 'bultfontein' 'delft'
#  'koppies' 'oudtshoorn' 'phoenix' 'sebokeng' 'orkney' 'atlantis'
#  'mafikeng' 'louis-trichardt' 'stanger' 'southbroom' 'walkerville'
#  'mokopane' 'groot-brakrivier' 'eikenhof' 'nsikazi' 'mtunzini'
#  'butterworth' 'swartruggens' 'hibberdene' 'volksrust' 'deneysville'
#  'blue-downs' 'camperdown' 'arniston' 'ermelo' 'st-helena-bay'
#  'prince-albert' 'grootvlei' 'steynsrus' 'struisbaai' 'bela-bela'
#  'christiana' 'philippolis' 'tongaat' 'barberton' 'mthatha' 'clarens'
#  'umzinto' 'umlazi' 'marquard' 'katlehong' 'hilton' 'waterval-boven'
#  'eshowe' 'piet-retief' 'worcester' 'napier' 'kathu' 'ga-rankuwa'
#  'hammanskraal' 'senekal' 'ottosdal' 'grabouw' 'seymour' 'philipstown'
#  'desainagar' 'trafalgar' 'la-mercy' 'vanrhynsdorp' 'queensburgh'
#  'allanridge' 'graaff-reinet' 'barkly-west' 'carletonville' 'vryheid'
#  'malmesbury' 'stanford' 'witsand' 'vredefort' 'sterkstroom' 'leandra'
#  'rayton' 'warrenton' 'thabazimbi' 'bethal' 'bonnievale' 'mabopane'
#  'greytown' 'vredenburg' 'siyabuswa' 'paterson' 'sedgefield' 'bot-river'
#  'kommetjie' 'hennenman' 'paternoster' 'scottburgh' 'lichtenburg'
#  'komatipoort' 'scarborough' 'hammarsdale' 'hartbeesfontein' 'esikhawini'
#  'wonderboom' 'machadodorp' 'gariepdam' 'bathurst' 'oranjeville'
#  'koffiefontein' 'boesmansriviermond' 'vleesbaai' 'kriel' 'wilderness'
#  'queenstown' 'st-lucia' 'bedford' 'riebeek-valley' 'malelane' 'barrydale'
#  'warden' 'calitzdorp' 'isipingo' 'umbumbulu' 'schweizer-reneke' 'temba'
#  'kenton-on-sea' 'touws-river' 'blythedale' 'aberdeen' 'ladybrand'
#  'ndwedwe' 'lady-grey' 'ficksburg' 'bulwer' nan 'umzumbe' 'hartswater'
#  'kwambonambi' 'agulhas' 'virginia' 'orania' 'dullstroom' 'hectorspruit'
#  'cape-st-francis' 'kleinsee' 'adams-mission' 'kokstad' 'stutterheim'
#  'phalaborwa' 'moorreesburg' 'mooi-river' 'swellendam' 'danielskuil'
#  'ventersdorp' 'graskop' 'marina-beach' 'elysium' 'ritchie' 'cullinan'
#  'winburg' 'reddersburg' 'jacobsbaai' 'vryburg' 'rietkuil' 'ladismith'
#  'pullens-hope' 'kuruman' 'hogsback' 'cedarville' 'hendrina' 'haga-haga'
#  'carolina' 'gouritsmond' 'dannhauser' 'giyani' 'koster' 'burgersfort'
#  'somerset-east' 'cintsa' 'amersfoort' 'ventersburg' 'port-nolloth'
#  'willowmore' 'northam' 'mooinooi' 'groblersdal' 'hertzogville'
#  'morgans-bay' 'de-aar' 'porterville' 'leeudoringstad' 'boknesstrand'
#  'gamtoos-mouth' 'harrismith' 'hazyview' 'kestell' 'reitz' 'albertinia'
#  'thornhill' 'keimoes' 'tarkastad' 'richmond' 'kaysers-beach'
#  'modjadjiskloof' 'clanwilliam' 'marble-hall' 'vierfontein'
#  'phuthaditjhaba' 'byrne' 'melmoth' 'viljoenskroon' 'blackheath'
#  'bothaville' 'utrecht' 'balfour' 'cradock' 'springbok' 'alexandria'
#  'aliwal-north' 'cathcart' 'villiersdorp' 'theunissen' 'hewu' 'vosburg'
#  'kenhardt' 'koingnaas' 'thaba-nchu' 'robertson' 'hopefield' 'garies'
#  'darnall' 'zeerust' 'postmasburg' 'vaalwater' 'trompsburg' 'macassar'
#  'riversdale' 'klein-brak-rivier' 'dundee' 'ceres' 'fouriesburg'
#  'smithfield' 'boshof' 'adelaide' 'matatiele' 'oyster-bay' 'glencoe'
#  'nottingham-road' 'kei-mouth' 'prieska' 'bloemhof' 'hoopstad' 'mankwe'
#  'zastron' 'loxton' 'groot-marico' 'calvinia' 'dealesville' 'clocolan'
#  'beaufort-west' 'douglas' 'lindley' 'groblershoop' 'musina' 'mogwase'
#  'bushbuckridge' 'colchester' 'edenville' 'pofadder' 'tonga' 'petrusburg'
#  'hobhouse' 'mandeni' 'stella' 'bhisho' 'colenso' 'mcgregor'
#  'strandfontein' 'lamberts-bay' 'louwsburg' 'kleinemonde' 'jan-kempdorp'
#  'baardskeerdersbos' 'venterstad' 'kwamhlanga' 'delareyville'
#  'barkly-east' 'kakamas' 'ganyesa' 'renovaal' 'port-st-johns'
#  'cathkin-park' 'ohrigstad' 'winterton' 'ashton' 'jacobsdal' 'tweeling'
#  'hermon' 'badplaas' 'colesberg' 'dewetsdorp' 'bethulie' 'whittlesea'
#  'kirkwood' 'coligny' 'excelsior' 'laingsburg' 'joubertina' 'olifantshoek'
#  'thohoyandou' 'graafwater' 'ulundi' 'hankey' 'bitterfontein' 'memel'
#  'eendrag' 'dordrecht' 'darling' 'fraserburg' 'tulbagh' 'cannon-rocks'
#  'piketberg' 'odendaalsrus' 'hotazel' 'cornubia' 'griekwastad' 'itsoseng'
#  'himeville']
# ------------
#
# Price >> [1395000. 4950000. 4999000. ... 2635000. 1058000. 2911800.]
# ------------
#
# Province >> ['gauteng' 'kwazulu-natal' 'western-cape' 'eastern-cape' 'free-state'
#  'limpopo' 'mpumalanga' 'north-west' 'northern-cape' nan]
# ------------
#
# Suburbaine >> ['weltevreden-park' 'sibaya-precinct' 'sandton-central' ...
#  'west-acres-ext-7' 'seaforth' 'grayleigh']
# ------------
#
# Dining Rooms >> [ 1. nan  2.  0.  3.  4. 10. 11.  5.  6.]
# ------------
#
# Garden >> [ 1. nan  2.]
# ------------
#
# Kitchens >> [ 1. nan  4.  2.]
# ------------
#
# Lounges >> [nan  1.  2.  3.  4.  5.]
# ------------

# %%
# add new column
# df["Bathrooms/Bedrooms"]= df["Bathrooms"] / df["Bedrooms"]

# %%
#taux de valeur manquante
missing_rate = df.isna().sum()/df.shape[0]

# %%
df.describe()
# Out:
#           Bathrooms      Bedrooms     Coverage  Domestic Rooms      Erf Size  \
# count  26274.000000  27379.000000  1856.000000     2686.000000  1.681200e+04
# mean       2.295501      3.236659    38.591595        1.066270  5.964602e+07
# std        1.825263      2.056131    26.014266        0.421138  7.717042e+09
# min        0.500000      0.500000     1.000000        1.000000  9.800000e-01
# 25%        1.000000      2.000000    21.000000        1.000000  3.640000e+02
# 50%        2.000000      3.000000    31.000000        1.000000  9.430000e+02
# 75%        2.500000      4.000000    50.000000        1.000000  1.884250e+03
# max       54.000000     82.000000   100.000000       14.000000  1.000600e+12
#
#        Family/TV Room     Floor Size        Garage         Levies  \
# count     2831.000000   16371.000000  14562.000000   13434.000000
# mean         1.818792     277.772402      1.854484    2016.813161
# std          1.244641    6236.413652      1.075881   13161.478373
# min          1.000000       1.000000      0.500000       0.000000
# 25%          1.000000      69.000000      1.000000     930.000000
# 50%          1.000000     108.000000      2.000000    1411.000000
# 75%          2.000000     220.000000      2.000000    2124.000000
# max         11.000000  750000.000000     29.000000  865000.000000
#
#        Nearby Public Transport  ...  Rates and Taxes  Reception Rooms  \
# count              1620.000000  ...     1.793600e+04      4030.000000
# mean                  1.777778  ...     2.827602e+03         1.641191
# std                   0.727132  ...     1.123337e+05         1.285616
# min                   1.000000  ...     0.000000e+00         1.000000
# 25%                   1.000000  ...     4.500000e+02         1.000000
# 50%                   2.000000  ...     7.845000e+02         1.000000
# 75%                   2.000000  ...     1.325000e+03         2.000000
# max                   3.000000  ...     1.380000e+07        46.000000
#
#        Special Features  Standalone Building  Temperature Control  \
# count      30941.000000         30941.000000         30941.000000
# mean           0.159756             0.050709             0.064510
# std            0.879217             0.219407             0.310203
# min            0.000000             0.000000             0.000000
# 25%            0.000000             0.000000             0.000000
# 50%            0.000000             0.000000             0.000000
# 75%            0.000000             0.000000             0.000000
# max           13.000000             1.000000             5.000000
#
#               Price  Dining Rooms        Garden      Kitchens       Lounges
# count  3.093800e+04  12587.000000  11384.000000  23499.000000  17122.000000
# mean   2.152073e+06      1.008024      1.000088      1.000170      1.018689
# std    3.163522e+06      0.192871      0.009372      0.020629      0.180534
# min    4.100000e+03      0.000000      1.000000      1.000000      1.000000
# 25%    7.450000e+05      1.000000      1.000000      1.000000      1.000000
# 50%    1.250000e+06      1.000000      1.000000      1.000000      1.000000
# 75%    2.399000e+06      1.000000      1.000000      1.000000      1.000000
# max    1.450000e+08     11.000000      2.000000      4.000000      5.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# ### Elimination des colonnes

# %%
# unused_columns = ['Listing Date','Listing Number']

# %%
for col in df.columns[missing_rate < 0.95]:
    if col not in df.columns[missing_rate < 0.90]:
        print(col)
# Out:
# Coverage
# Domestic Rooms
# Family/TV Room
# Nearby Public Transport
# Style
# Window

# %%
#On elimine les variables à valeur manquante à 95%
df = df[df.columns[missing_rate < 0.90]]

# %%
# df = df.drop(unused_columns,axis=1)

# %%
df.shape
# Out:
# (30941, 28)

# %%
# def transform_floor_size(value):
#     value = str(value)
#     value = value.replace("m²", "")
#     value = value.replace(" ","")
#     return float(value)

# %%
# df['Floor Size'] = df['Floor Size'].map(transform_floor_size)

# %%
# df['Erf Size'].unique()

# %%
# def transform_erf_size(value):
#     value = str(value)
#     if 'ha' in value:
#         value = value.replace("ha", "")
#         value = value.replace("s","")
#         value = value.replace(" ","")
#         return float(value)*10000
#     elif 'acre' in value:
#         value = value.replace("acre", "")
#         value = value.replace("s","")
#         value = value.replace(" ","")
#         return float(value)*4046.86
#     else:
#         value = value.replace("m²", "")
#         value = value.replace(" ","")
#         return float(value)

# %%
# df['Erf Size'] = df['Erf Size'].map(transform_erf_size)

# %%
# df.dtypes.value_counts()

# %%
# df['Town'].unique().shape

# %%
# df['Type of Property'].value_counts()

# %%
df = df[~df["Price"].isna()]

# %%
# drop to reduced X
# df = df.drop(["Bathrooms","Bedrooms"],axis=1)

# %% [markdown]
# ### Elimination des entrées sans prix

# %%
# mask = df['Price'].isna()
# df = df[~mask]
# df['Price'].isna().sum()

# %% [markdown]
# ## TrainTest - Nettoyage - Encodage

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
trainset, testset = train_test_split(df, test_size=0.2, random_state=0)

# %%
# trainset['Town'].value_counts().shape

# %%
# testset['Town'].value_counts().shape

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder, RobustScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_selector

# %%
def encodage():

    categorical_features = [
                            'Wall','City','Province','Suburbaine',
                            'Type of Property', "Roof", "Security"
                        ]
    
    integer_features = [
        "Bathrooms", "Bedrooms",
        "Garage", "Parking", 
          "Reception Rooms", "Special Features", 
        "Temperature Control", "Dining Rooms", "Garden", "Kitchens", "Lounges", 
        "No Transfer Duty", "Office","Pets Allowed", "Standalone Building"
    ]
    
#     integer_features = make_column_selector(dtype_include=np.number)
    
    print(len(categorical_features))
    print(len(integer_features))
    
    size_features = ['Erf Size', 'Floor Size', 'Price per m²', 'Rates and Taxes', 'Levies']
    
    categorical_pipeline = make_pipeline(SimpleImputer(strategy='most_frequent'),OneHotEncoder(handle_unknown = "ignore"))
    
    
    size_pipeline = make_pipeline(SimpleImputer(),StandardScaler())
    
    preprocessor = make_column_transformer((categorical_pipeline,categorical_features),
                                          (SimpleImputer(strategy='mean'),integer_features),
                                          (size_pipeline,size_features))
    return preprocessor

# %%
def preprocessing(df):
    X = df.drop('Price',axis=1)
    y = df['Price']
    
    return X, y

# %%
X_train, y_train = preprocessing(trainset)

# %%
X_test, y_test = preprocessing(testset)

# %% [markdown]
# # Modelisation

# %%
from sklearn.linear_model import LinearRegression, Ridge,  HuberRegressor, Lasso
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %%
preprocessor = encodage()
# Out:
# 7
# 15

# %%
LinearReg = make_pipeline(preprocessor, LinearRegression())
ridge = make_pipeline(preprocessor, Ridge())
lasso = make_pipeline(preprocessor, Lasso())
HuberReg = make_pipeline(preprocessor,HuberRegressor())
RandomForestReg = make_pipeline(preprocessor, RandomForestRegressor())
XGBReg = make_pipeline(preprocessor, XGBRegressor())

# %%
dict_of_models = {'LinearReg': LinearReg,
                  'ridge' : ridge,
                  'lasso': lasso,
                  'HuberReg': HuberReg,
                  'RandomForest': RandomForestReg,
                  'Xgb': XGBReg
                 }

# %% [markdown]
# ## Procédure d'évaluation

# %%
from sklearn.metrics import make_scorer
from sklearn.model_selection import learning_curve

# %%
def RMSE(y_test, y_pred):
    error = np.square(np.subtract(np.log(y_test),np.log(y_pred))).mean()
#     error = np.square(np.subtract(y_test,y_pred)).mean()
    error = np.sqrt(error)
    return error

# %%
def normal_error(y_test, y_pred):
    error = np.abs(y_test - y_pred).sum() / y_test.shape[0]
    return error

# %%
#scoring customized
my_scorer = make_scorer(RMSE, greater_is_better=True)

# %%
def evaluation(model):
    
    print(X_train)     
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    print("Normal Mean Error: ", normal_error(y_test, y_pred))
    print('Root Mean Squared Error: ',RMSE(y_test, y_pred))
    
    N, train_score, val_score = learning_curve(model, X_train, y_train,
                                              cv=4,train_sizes=np.linspace(0.1, 1, 10))
    
    
    plt.figure(figsize=(12, 8))
    plt.plot(N, train_score.mean(axis=1), label='train score')
    plt.plot(N, val_score.mean(axis=1), label='validation score')
    plt.legend()
    plt.show()

# %%
print("Linear Regression")
evaluation(LinearReg)
# Out:
# Linear Regression
#        Bathrooms  Bedrooms   Erf Size  Floor Size  Garage  Levies  \
# 16400        3.0       3.0  7150000.0         NaN     NaN     NaN
# 7519         5.5       5.0     2067.0         NaN     3.0     NaN
# 19698        2.0       3.0        NaN       222.0     NaN     NaN
# 30210        2.0       5.0    17800.0         NaN     1.0     NaN
# 220          1.0       3.0      300.0       133.0     NaN     NaN
# ...          ...       ...        ...         ...     ...     ...
# 13123        1.0       NaN        NaN        48.0     NaN  1913.0
# 19648        1.0       2.0    43089.0        83.0     NaN     NaN
# 9845         2.5       3.0        NaN         NaN     1.0     NaN
# 10799        3.0       5.0      991.0         NaN     NaN  1000.0
# 2732         1.0       2.0        NaN        74.0     NaN  2148.0
#
#        No Transfer Duty  Office  Parking  Pets Allowed  ...  \
# 16400                 0       0      0.0             1  ...
# 7519                  0       0     10.0             1  ...
# 19698                 0       0      0.0             0  ...
# 30210                 0       0      1.0             0  ...
# 220                   0       0      0.0             0  ...
# ...                 ...     ...      ...           ...  ...
# 13123                 0       0      0.0             0  ...
# 19648                 0       0      2.0             0  ...
# 9845                  0       0      0.0             0  ...
# 10799                 0       1      0.0             1  ...
# 2732                  0       0      0.0             0  ...
#
#        Temperature Control  Type of Property     Wall         City  \
# 16400                    0         Townhouse      NaN      witbank
# 7519                     0             House      NaN      sandton
# 19698                    0             House      NaN    cape-town
# 30210                    0             House      NaN  randfontein
# 220                      0             House      NaN   soshanguve
# ...                    ...               ...      ...          ...
# 13123                    0  Apartment / Flat  Plaster     hermanus
# 19648                    0  Apartment / Flat      NaN    lephalale
# 9845                     0  Apartment / Flat      NaN   middelburg
# 10799                    0             House      NaN       akasia
# 2732                     0  Apartment / Flat      NaN      sandton
#
#            Province          Suburbaine  Dining Rooms  Garden Kitchens Lounges
# 16400    mpumalanga         reyno-ridge           NaN     NaN      1.0     1.0
# 7519        gauteng              atholl           1.0     1.0      1.0     1.0
# 19698  western-cape         observatory           1.0     NaN      1.0     1.0
# 30210       gauteng           bootha-ah           1.0     1.0      1.0     NaN
# 220         gauteng        soshanguve-l           NaN     NaN      1.0     1.0
# ...             ...                 ...           ...     ...      ...     ...
# 13123  western-cape           westcliff           NaN     1.0      1.0     NaN
# 19648       limpopo          onverwacht           NaN     NaN      1.0     1.0
# 9845     mpumalanga  middelburg-central           NaN     NaN      NaN     NaN
# 10799       gauteng        the-orchards           NaN     1.0      NaN     NaN
# 2732        gauteng            paulshof           NaN     NaN      NaN     NaN
#
# [24750 rows x 27 columns]
# Normal Mean Error:  1224091.1292595614
# Root Mean Squared Error:  0.7458638991816576
# <ipython-input-408-2ea666a4f6a0>:2: RuntimeWarning: invalid value encountered in log
#   error = np.square(np.subtract(np.log(y_test),np.log(y_pred))).mean()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-412-9e577515205f> in <module>
#       1 print("Linear Regression")
# ----> 2 evaluation(LinearReg)
#
# <ipython-input-411-82b3d4234bcc> in evaluation(model)
#       8     print('Root Mean Squared Error: ',RMSE(y_test, y_pred))
#       9
# ---> 10     N, train_score, val_score = learning_curve(model, X_train, y_train,
#      11                                               cv=4,train_sizes=np.linspace(0.1, 1, 10))
#      12
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in learning_curve(estimator, X, y, groups, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, verbose, shuffle, random_state, error_score, return_times, fit_params)
#    1410                 train_test_proportions.append((train[:n_train_samples], test))
#    1411
# -> 1412         results = parallel(delayed(_fit_and_score)(
#    1413             clone(estimator), X, y, scorer, train, test, verbose,
#    1414             parameters=None, fit_params=fit_params, return_train_score=True,
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~/.local/lib/python3.9/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/.local/lib/python3.9/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~/.local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     596             estimator.fit(X_train, **fit_params)
#     597         else:
# --> 598             estimator.fit(X_train, y_train, **fit_params)
#     599
#     600     except Exception as e:
#
# ~/.local/lib/python3.9/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# ~/.local/lib/python3.9/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     555
#     556             if y.ndim < 2:
# --> 557                 out = sparse_lsqr(X_centered, y)
#     558                 self.coef_ = out[0]
#     559                 self._residues = out[3]
#
# ~/.local/lib/python3.9/site-packages/scipy/sparse/linalg/isolve/lsqr.py in lsqr(A, b, damp, atol, btol, conlim, iter_lim, show, calc_var, x0)
#     415         %                alfa*v  =  A'*u  -  beta*v.
#     416         """
# --> 417         u = A.matvec(v) - alfa * u
#     418         beta = np.linalg.norm(u)
#     419
#
# ~/.local/lib/python3.9/site-packages/scipy/sparse/linalg/interface.py in matvec(self, x)
#     230             raise ValueError('dimension mismatch')
#     231
# --> 232         y = self._matvec(x)
#     233
#     234         if isinstance(x, np.matrix):
#
# ~/.local/lib/python3.9/site-packages/scipy/sparse/linalg/interface.py in _matvec(self, x)
#     528
#     529     def _matvec(self, x):
# --> 530         return self.__matvec_impl(x)
#     531
#     532     def _rmatvec(self, x):
#
# ~/.local/lib/python3.9/site-packages/sklearn/linear_model/_base.py in matvec(b)
#     545
#     546             def matvec(b):
# --> 547                 return X.dot(b) - b.dot(X_offset_scale)
#     548
#     549             def rmatvec(b):
#
# ~/.local/lib/python3.9/site-packages/scipy/sparse/base.py in dot(self, other)
#     357
#     358         """
# --> 359         return self * other
#     360
#     361     def power(self, n, dtype=None):
#
# ~/.local/lib/python3.9/site-packages/scipy/sparse/base.py in __mul__(self, other)
#     465             # Fast path for the most common case
#     466             if other.shape == (N,):
# --> 467                 return self._mul_vector(other)
#     468             elif other.shape == (N, 1):
#     469                 return self._mul_vector(other.ravel()).reshape(M, 1)
#
# ~/.local/lib/python3.9/site-packages/scipy/sparse/compressed.py in _mul_vector(self, other)
#     476         # csr_matvec or csc_matvec
#     477         fn = getattr(_sparsetools, self.format + '_matvec')
# --> 478         fn(M, N, self.indptr, self.indices, self.data, other, result)
#     479
#     480         return result
#
# KeyboardInterrupt:

# %%
LinearReg.fit(X_train, y_train)
y_pred = LinearReg.predict(X_test)

# %%
LinearReg.score(X_test, y_test)
# Out:
# -5.499842589366054

# %%
X0 = X_test.iloc[0,:]

# %%
y_pred[1:10]
# Out:
# array([4520678.19762696,  919733.21222977, 7878627.4780681 ,
#        5503254.6232678 ,  595776.15679808, 1511158.23696576,
#         529037.52072597, 1184431.31036419, 3303983.30719583])

# %%
y_test.iloc[1:10]
# Out:
# 28556    5495000.0
# 21371     799000.0
# 15656    5495000.0
# 18980    4100000.0
# 276      1725000.0
# 23136     795000.0
# 29131     650000.0
# 14091     689000.0
# 12116    3334500.0
# Name: Price, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     819             try:
# --> 820                 tasks = self._ready_batches.get(block=False)
#     821             except queue.Empty:
#
# /usr/lib/python3.9/queue.py in get(self, block, timeout)
#     167                 if not self._qsize():
# --> 168                     raise Empty
#     169             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-379-15ee1ebd325e> in <module>
# ----> 1 LinearReg.predict(X0)
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     118
#     119         # lambda, but not partial, allows help() to work with update_wrapper
# --> 120         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     121         # update the docstring of the returned function
#     122         update_wrapper(out, self.fn)
#
# ~/.local/lib/python3.9/site-packages/sklearn/pipeline.py in predict(self, X, **predict_params)
#     416         Xt = X
#     417         for _, name, transform in self._iter(with_final=False):
# --> 418             Xt = transform.transform(Xt)
#     419         return self.steps[-1][-1].predict(Xt, **predict_params)
#     420
#
# ~/.local/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py in transform(self, X)
#     562                 "data given during fit."
#     563             )
# --> 564         Xs = self._fit_transform(X, None, _transform_one, fitted=True)
#     565         self._validate_output(Xs)
#     566
#
# ~/.local/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py in _fit_transform(self, X, y, func, fitted)
#     432             self._iter(fitted=fitted, replace_strings=True))
#     433         try:
# --> 434             return Parallel(n_jobs=self.n_jobs)(
#     435                 delayed(func)(
#     436                     transformer=clone(trans) if not fitted else trans,
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
#    1042                 self._iterating = self._original_iterator is not None
#    1043
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     829                 big_batch_size = batch_size * n_jobs
#     830
# --> 831                 islice = list(itertools.islice(iterator, big_batch_size))
#     832                 if len(islice) == 0:
#     833                     return False
#
# ~/.local/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py in <genexpr>(.0)
#     435                 delayed(func)(
#     436                     transformer=clone(trans) if not fitted else trans,
# --> 437                     X=_safe_indexing(X, column, axis=1),
#     438                     y=y,
#     439                     weight=weight,
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/__init__.py in _safe_indexing(X, indices, axis)
#     334
#     335     if axis == 1 and indices_dtype == 'str' and not hasattr(X, 'loc'):
# --> 336         raise ValueError(
#     337             "Specifying the columns using strings is only supported for "
#     338             "pandas DataFrames"
#
# ValueError: Specifying the columns using strings is only supported for pandas DataFrames

# %%
print("Ridge")
evaluation(ridge)
# Out:
# Ridge
#        Bathrooms  Bedrooms  Coverage  Domestic Rooms   Erf Size  \
# 16400        3.0       3.0       NaN             NaN  7150000.0
# 7519         5.5       5.0       NaN             1.0     2067.0
# 19698        2.0       3.0       NaN             NaN        NaN
# 30210        2.0       5.0       NaN             NaN    17800.0
# 220          1.0       3.0       NaN             NaN      300.0
# ...          ...       ...       ...             ...        ...
# 13123        1.0       NaN       NaN             NaN        NaN
# 19648        1.0       2.0       NaN             NaN    43089.0
# 9845         2.5       3.0       NaN             NaN        NaN
# 10799        3.0       5.0       NaN             NaN      991.0
# 2732         1.0       2.0       NaN             NaN        NaN
#
#        Family/TV Room  Floor Size  Garage  Levies  Nearby Public Transport  \
# 16400             NaN         NaN     NaN     NaN                      NaN
# 7519              NaN         NaN     3.0     NaN                      NaN
# 19698             NaN       222.0     NaN     NaN                      NaN
# 30210             4.0         NaN     1.0     NaN                      NaN
# 220               NaN       133.0     NaN     NaN                      NaN
# ...               ...         ...     ...     ...                      ...
# 13123             NaN        48.0     NaN  1913.0                      NaN
# 19648             NaN        83.0     NaN     NaN                      NaN
# 9845              NaN         NaN     1.0     NaN                      NaN
# 10799             NaN         NaN     NaN  1000.0                      NaN
# 2732              NaN        74.0     NaN  2148.0                      NaN
#
#        ...  Type of Property     Wall           Window         City  \
# 16400  ...         Townhouse      NaN              NaN      witbank
# 7519   ...             House      NaN              NaN      sandton
# 19698  ...             House      NaN              NaN    cape-town
# 30210  ...             House      NaN              NaN  randfontein
# 220    ...             House      NaN              NaN   soshanguve
# ...    ...               ...      ...              ...          ...
# 13123  ...  Apartment / Flat  Plaster  Wood, Aluminium     hermanus
# 19648  ...  Apartment / Flat      NaN              NaN    lephalale
# 9845   ...  Apartment / Flat      NaN              NaN   middelburg
# 10799  ...             House      NaN              NaN       akasia
# 2732   ...  Apartment / Flat      NaN              NaN      sandton
#
#            Province          Suburbaine  Dining Rooms Garden Kitchens  Lounges
# 16400    mpumalanga         reyno-ridge           NaN    NaN      1.0      1.0
# 7519        gauteng              atholl           1.0    1.0      1.0      1.0
# 19698  western-cape         observatory           1.0    NaN      1.0      1.0
# 30210       gauteng           bootha-ah           1.0    1.0      1.0      NaN
# 220         gauteng        soshanguve-l           NaN    NaN      1.0      1.0
# ...             ...                 ...           ...    ...      ...      ...
# 13123  western-cape           westcliff           NaN    1.0      1.0      NaN
# 19648       limpopo          onverwacht           NaN    NaN      1.0      1.0
# 9845     mpumalanga  middelburg-central           NaN    NaN      NaN      NaN
# 10799       gauteng        the-orchards           NaN    1.0      NaN      NaN
# 2732        gauteng            paulshof           NaN    NaN      NaN      NaN
#
# [24750 rows x 33 columns]
# Root Mean Squared Error:  2590449.588085969

# %%
print("Robust Regression")
evaluation(HuberReg)
# Out:
# Robust Regression
#        Bathrooms  Bedrooms  Coverage  Domestic Rooms   Erf Size  \
# 16400        3.0       3.0       NaN             NaN  7150000.0
# 7519         5.5       5.0       NaN             1.0     2067.0
# 19698        2.0       3.0       NaN             NaN        NaN
# 30210        2.0       5.0       NaN             NaN    17800.0
# 220          1.0       3.0       NaN             NaN      300.0
# ...          ...       ...       ...             ...        ...
# 13123        1.0       NaN       NaN             NaN        NaN
# 19648        1.0       2.0       NaN             NaN    43089.0
# 9845         2.5       3.0       NaN             NaN        NaN
# 10799        3.0       5.0       NaN             NaN      991.0
# 2732         1.0       2.0       NaN             NaN        NaN
#
#        Family/TV Room  Floor Size  Garage  Levies  Nearby Public Transport  \
# 16400             NaN         NaN     NaN     NaN                      NaN
# 7519              NaN         NaN     3.0     NaN                      NaN
# 19698             NaN       222.0     NaN     NaN                      NaN
# 30210             4.0         NaN     1.0     NaN                      NaN
# 220               NaN       133.0     NaN     NaN                      NaN
# ...               ...         ...     ...     ...                      ...
# 13123             NaN        48.0     NaN  1913.0                      NaN
# 19648             NaN        83.0     NaN     NaN                      NaN
# 9845              NaN         NaN     1.0     NaN                      NaN
# 10799             NaN         NaN     NaN  1000.0                      NaN
# 2732              NaN        74.0     NaN  2148.0                      NaN
#
#        ...  Type of Property     Wall           Window         City  \
# 16400  ...         Townhouse      NaN              NaN      witbank
# 7519   ...             House      NaN              NaN      sandton
# 19698  ...             House      NaN              NaN    cape-town
# 30210  ...             House      NaN              NaN  randfontein
# 220    ...             House      NaN              NaN   soshanguve
# ...    ...               ...      ...              ...          ...
# 13123  ...  Apartment / Flat  Plaster  Wood, Aluminium     hermanus
# 19648  ...  Apartment / Flat      NaN              NaN    lephalale
# 9845   ...  Apartment / Flat      NaN              NaN   middelburg
# 10799  ...             House      NaN              NaN       akasia
# 2732   ...  Apartment / Flat      NaN              NaN      sandton
#
#            Province          Suburbaine  Dining Rooms Garden Kitchens  Lounges
# 16400    mpumalanga         reyno-ridge           NaN    NaN      1.0      1.0
# 7519        gauteng              atholl           1.0    1.0      1.0      1.0
# 19698  western-cape         observatory           1.0    NaN      1.0      1.0
# 30210       gauteng           bootha-ah           1.0    1.0      1.0      NaN
# 220         gauteng        soshanguve-l           NaN    NaN      1.0      1.0
# ...             ...                 ...           ...    ...      ...      ...
# 13123  western-cape           westcliff           NaN    1.0      1.0      NaN
# 19648       limpopo          onverwacht           NaN    NaN      1.0      1.0
# 9845     mpumalanga  middelburg-central           NaN    NaN      NaN      NaN
# 10799       gauteng        the-orchards           NaN    1.0      NaN      NaN
# 2732        gauteng            paulshof           NaN    NaN      NaN      NaN
#
# [24750 rows x 33 columns]
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Root Mean Squared Error:  14140975.603114221
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_huber.py:296: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
print("Lasso")
evaluation(lasso)
# Out:
# Lasso
#        Bathrooms  Bedrooms  Coverage  Domestic Rooms   Erf Size  \
# 16400        3.0       3.0       NaN             NaN  7150000.0
# 7519         5.5       5.0       NaN             1.0     2067.0
# 19698        2.0       3.0       NaN             NaN        NaN
# 30210        2.0       5.0       NaN             NaN    17800.0
# 220          1.0       3.0       NaN             NaN      300.0
# ...          ...       ...       ...             ...        ...
# 13123        1.0       NaN       NaN             NaN        NaN
# 19648        1.0       2.0       NaN             NaN    43089.0
# 9845         2.5       3.0       NaN             NaN        NaN
# 10799        3.0       5.0       NaN             NaN      991.0
# 2732         1.0       2.0       NaN             NaN        NaN
#
#        Family/TV Room  Floor Size  Garage  Levies  Nearby Public Transport  \
# 16400             NaN         NaN     NaN     NaN                      NaN
# 7519              NaN         NaN     3.0     NaN                      NaN
# 19698             NaN       222.0     NaN     NaN                      NaN
# 30210             4.0         NaN     1.0     NaN                      NaN
# 220               NaN       133.0     NaN     NaN                      NaN
# ...               ...         ...     ...     ...                      ...
# 13123             NaN        48.0     NaN  1913.0                      NaN
# 19648             NaN        83.0     NaN     NaN                      NaN
# 9845              NaN         NaN     1.0     NaN                      NaN
# 10799             NaN         NaN     NaN  1000.0                      NaN
# 2732              NaN        74.0     NaN  2148.0                      NaN
#
#        ...  Type of Property     Wall           Window         City  \
# 16400  ...         Townhouse      NaN              NaN      witbank
# 7519   ...             House      NaN              NaN      sandton
# 19698  ...             House      NaN              NaN    cape-town
# 30210  ...             House      NaN              NaN  randfontein
# 220    ...             House      NaN              NaN   soshanguve
# ...    ...               ...      ...              ...          ...
# 13123  ...  Apartment / Flat  Plaster  Wood, Aluminium     hermanus
# 19648  ...  Apartment / Flat      NaN              NaN    lephalale
# 9845   ...  Apartment / Flat      NaN              NaN   middelburg
# 10799  ...             House      NaN              NaN       akasia
# 2732   ...  Apartment / Flat      NaN              NaN      sandton
#
#            Province          Suburbaine  Dining Rooms Garden Kitchens  Lounges
# 16400    mpumalanga         reyno-ridge           NaN    NaN      1.0      1.0
# 7519        gauteng              atholl           1.0    1.0      1.0      1.0
# 19698  western-cape         observatory           1.0    NaN      1.0      1.0
# 30210       gauteng           bootha-ah           1.0    1.0      1.0      NaN
# 220         gauteng        soshanguve-l           NaN    NaN      1.0      1.0
# ...             ...                 ...           ...    ...      ...      ...
# 13123  western-cape           westcliff           NaN    1.0      1.0      NaN
# 19648       limpopo          onverwacht           NaN    NaN      1.0      1.0
# 9845     mpumalanga  middelburg-central           NaN    NaN      NaN      NaN
# 10799       gauteng        the-orchards           NaN    1.0      NaN      NaN
# 2732        gauteng            paulshof           NaN    NaN      NaN      NaN
#
# [24750 rows x 33 columns]
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:513: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.6156048586554696e+16, tolerance: 25297108812768.848
#   model = cd_fast.sparse_enet_coordinate_descent(
# <ipython-input-322-f6b4c6b8365e>:2: RuntimeWarning: invalid value encountered in log
#   error = np.square(np.subtract(np.log(y_test),np.log(y_pred))).mean()
# Root Mean Squared Error:  0.7495387593479994
# /home/sarobidy/.local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:513: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 757803648433083.6, tolerance: 1328342141633.3948
#   model = cd_fast.sparse_enet_coordinate_descent(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-335-fdeccf3c074e> in <module>
#       1 print("Lasso")
# ----> 2 evaluation(lasso)
#
# <ipython-input-324-41f9bd4e6b05> in evaluation(model)
#       7     print('Root Mean Squared Error: ',RMSE(y_test, y_pred))
#       8
# ----> 9     N, train_score, val_score = learning_curve(model, X_train, y_train,
#      10                                               cv=4,train_sizes=np.linspace(0.1, 1, 10))
#      11
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in learning_curve(estimator, X, y, groups, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, verbose, shuffle, random_state, error_score, return_times, fit_params)
#    1410                 train_test_proportions.append((train[:n_train_samples], test))
#    1411
# -> 1412         results = parallel(delayed(_fit_and_score)(
#    1413             clone(estimator), X, y, scorer, train, test, verbose,
#    1414             parameters=None, fit_params=fit_params, return_train_score=True,
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~/.local/lib/python3.9/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/.local/lib/python3.9/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~/.local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     596             estimator.fit(X_train, **fit_params)
#     597         else:
# --> 598             estimator.fit(X_train, y_train, **fit_params)
#     599
#     600     except Exception as e:
#
# ~/.local/lib/python3.9/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# ~/.local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py in fit(self, X, y, sample_weight, check_input)
#     842                 this_Xy = None
#     843             _, this_coef, this_dual_gap, this_iter = \
# --> 844                 self.path(X, y[:, k],
#     845                           l1_ratio=self.l1_ratio, eps=None,
#     846                           n_alphas=None, alphas=[alpha],
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     511         l2_reg = alpha * (1.0 - l1_ratio) * n_samples
#     512         if not multi_output and sparse.isspmatrix(X):
# --> 513             model = cd_fast.sparse_enet_coordinate_descent(
#     514                 coef_, l1_reg, l2_reg, X.data, X.indices,
#     515                 X.indptr, y, X_sparse_scaling,
#
# sklearn/linear_model/_cd_fast.pyx in sklearn.linear_model._cd_fast.sparse_enet_coordinate_descent()
#
# KeyboardInterrupt:

# %% [markdown]
# ## OPTIMISATION

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import PolynomialFeatures

# %%
ridge
# Out:
# Pipeline(memory=None,
#          steps=[('columntransformer',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(memory=None,
#                                                            steps=[('simpleimputer',
#                                                                    SimpleImputer(add_indicator=False,
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='most_frequent',
#                                                                                  verbose=0)),
#                                                                   ('onehotencoder',
#                                                                    On...
#                                                                                  copy=True,
#                                                                                  fill_value=None,
#                                                                                  missing_values=nan,
#                                                                                  strategy='mean',
#                                                                                  verbose=0)),
#                                                                   ('standardscaler',
#                                                                    StandardScaler(copy=True,
#                                                                                   with_mean=True,
#                                                                                   with_std=True))],
#                                                            verbose=False),
#                                                   ['Erf Size', 'Floor Size'])],
#                                    verbose=False)),
#                 ('ridge',
#                  Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                        max_iter=None, normalize=False, random_state=None,
#                        solver='auto', tol=0.001))],
#          verbose=False)

# %%
hyper_params = {'ridge__alpha' : np.linspace(0.1,1,10)
               }

# %%
grid = GridSearchCV(ridge, hyper_params, scoring=my_scorer, cv=4)

# %%
grid.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
# {'ridge__alpha': 0.2}
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %%
print(grid.best_params_)
# Out:
# {'ridge__alpha': 0.2}

# %%
model_final = grid.best_estimator_
evaluation(model_final)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
# Root Mean Squared Error:  0.7371800569970649

# %%
ridge_pol = make_pipeline(preprocessor,PolynomialFeatures(2), Ridge(alpha=0.2))

ridge_pol.fit(X_train, y_train)
y_pred = ridge_pol.predict(X_test)

print('Root Mean Squared Error: ',RMSE(y_test, y_pred))
# Out:
# Root Mean Squared Error:  0.6218467971239166
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %%
hyper_params = {'polynomialfeatures__degree' : [2,3],
                'ridge__alpha' : np.linspace(0.1,1,10)
               }
grid_pol = RandomizedSearchCV(ridge_pol, hyper_params, scoring='neg_mean_squared_error', cv=4,
                          n_iter=5)

# %% [markdown]
# ### Evaluation avec my_scorer

# %%
def evaluation_my_scorer(model):
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    print('Root Mean Squared Error: ',RMSE(y_test, y_pred))
    
    N, train_score, val_score = learning_curve(model, X_train, y_train,scoring=my_scorer,
                                              cv=4,train_sizes=np.linspace(0.1, 1, 10))
    
    
    plt.figure(figsize=(12, 8))
    plt.plot(N, train_score.mean(axis=1), label='train score')
    plt.plot(N, val_score.mean(axis=1), label='validation score')
    plt.legend()
    plt.show()

# %%
evaluation_my_scorer(LinearReg)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
# Root Mean Squared Error:  0.7422742299982947
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %%
evaluation_my_scorer(ridge)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
# Root Mean Squared Error:  0.7459426842553379
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %%
evaluation_my_scorer(HuberReg)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
# Root Mean Squared Error:  0.585057119502565
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log

# %%
# evaluation RandomForest

# %%
evaluation(RandomForestReg)
# Out:
#        Bathrooms  Bedrooms  Coverage  Domestic Rooms   Erf Size  \
# 16400        3.0       3.0       NaN             NaN  7150000.0
# 7519         5.5       5.0       NaN             1.0     2067.0
# 19698        2.0       3.0       NaN             NaN        NaN
# 30210        2.0       5.0       NaN             NaN    17800.0
# 220          1.0       3.0       NaN             NaN      300.0
# ...          ...       ...       ...             ...        ...
# 13123        1.0       NaN       NaN             NaN        NaN
# 19648        1.0       2.0       NaN             NaN    43089.0
# 9845         2.5       3.0       NaN             NaN        NaN
# 10799        3.0       5.0       NaN             NaN      991.0
# 2732         1.0       2.0       NaN             NaN        NaN
#
#        Family/TV Room  Floor Size  Garage  Levies  Nearby Public Transport  \
# 16400             NaN         NaN     NaN     NaN                      NaN
# 7519              NaN         NaN     3.0     NaN                      NaN
# 19698             NaN       222.0     NaN     NaN                      NaN
# 30210             4.0         NaN     1.0     NaN                      NaN
# 220               NaN       133.0     NaN     NaN                      NaN
# ...               ...         ...     ...     ...                      ...
# 13123             NaN        48.0     NaN  1913.0                      NaN
# 19648             NaN        83.0     NaN     NaN                      NaN
# 9845              NaN         NaN     1.0     NaN                      NaN
# 10799             NaN         NaN     NaN  1000.0                      NaN
# 2732              NaN        74.0     NaN  2148.0                      NaN
#
#        ...  Type of Property     Wall           Window         City  \
# 16400  ...         Townhouse      NaN              NaN      witbank
# 7519   ...             House      NaN              NaN      sandton
# 19698  ...             House      NaN              NaN    cape-town
# 30210  ...             House      NaN              NaN  randfontein
# 220    ...             House      NaN              NaN   soshanguve
# ...    ...               ...      ...              ...          ...
# 13123  ...  Apartment / Flat  Plaster  Wood, Aluminium     hermanus
# 19648  ...  Apartment / Flat      NaN              NaN    lephalale
# 9845   ...  Apartment / Flat      NaN              NaN   middelburg
# 10799  ...             House      NaN              NaN       akasia
# 2732   ...  Apartment / Flat      NaN              NaN      sandton
#
#            Province          Suburbaine  Dining Rooms Garden Kitchens  Lounges
# 16400    mpumalanga         reyno-ridge           NaN    NaN      1.0      1.0
# 7519        gauteng              atholl           1.0    1.0      1.0      1.0
# 19698  western-cape         observatory           1.0    NaN      1.0      1.0
# 30210       gauteng           bootha-ah           1.0    1.0      1.0      NaN
# 220         gauteng        soshanguve-l           NaN    NaN      1.0      1.0
# ...             ...                 ...           ...    ...      ...      ...
# 13123  western-cape           westcliff           NaN    1.0      1.0      NaN
# 19648       limpopo          onverwacht           NaN    NaN      1.0      1.0
# 9845     mpumalanga  middelburg-central           NaN    NaN      NaN      NaN
# 10799       gauteng        the-orchards           NaN    1.0      NaN      NaN
# 2732        gauteng            paulshof           NaN    NaN      NaN      NaN
#
# [24750 rows x 33 columns]

# %% [markdown]
# # Final Model

# %%
# fm stands for FinalModel
fm = make_pipeline(preprocessor, RandomForestRegressor(n_estimators=200, random_state=0))

# %%
fm
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Wall', 'Security', 'Roof',
#                                                    'City', 'Province',
#                                                    'Suburbaine',
#                                                    'Type of Property']),
#                                                  ('simpleimputer',
#                                                   SimpleImputer(strategy='constant'),
#                                                   ['Bath...
#                                                    'Dining Rooms', 'Garden',
#                                                    'Kitchens', 'Lounges',
#                                                    'No Transfer Duty', 'Office',
#                                                    'Pets Allowed',
#                                                    'Standalone Building']),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer()),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['Erf Size', 'Floor Size',
#                                                    'Price per m²',
#                                                    'Rates and Taxes',
#                                                    'Levies'])])),
#                 ('randomforestregressor',
#                  RandomForestRegressor(n_estimators=200, random_state=0))])

# %%
help(RandomForestRegressor)
# Out:
# Help on class RandomForestRegressor in module sklearn.ensemble._forest:
#
# class RandomForestRegressor(ForestRegressor)
#  |  RandomForestRegressor(n_estimators=100, *, criterion='mse', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, ccp_alpha=0.0, max_samples=None)
#  |
#  |  A random forest regressor.
#  |
#  |  A random forest is a meta estimator that fits a number of classifying
#  |  decision trees on various sub-samples of the dataset and uses averaging
#  |  to improve the predictive accuracy and control over-fitting.
#  |  The sub-sample size is controlled with the `max_samples` parameter if
#  |  `bootstrap=True` (default), otherwise the whole dataset is used to build
#  |  each tree.
#  |
#  |  Read more in the :ref:`User Guide <forest>`.
#  |
#  |  Parameters
#  |  ----------
#  |  n_estimators : int, default=100
#  |      The number of trees in the forest.
#  |
#  |      .. versionchanged:: 0.22
#  |         The default value of ``n_estimators`` changed from 10 to 100
#  |         in 0.22.
#  |
#  |  criterion : {"mse", "mae"}, default="mse"
#  |      The function to measure the quality of a split. Supported criteria
#  |      are "mse" for the mean squared error, which is equal to variance
#  |      reduction as feature selection criterion, and "mae" for the mean
#  |      absolute error.
#  |
#  |      .. versionadded:: 0.18
#  |         Mean Absolute Error (MAE) criterion.
#  |
#  |  max_depth : int, default=None
#  |      The maximum depth of the tree. If None, then nodes are expanded until
#  |      all leaves are pure or until all leaves contain less than
#  |      min_samples_split samples.
#  |
#  |  min_samples_split : int or float, default=2
#  |      The minimum number of samples required to split an internal node:
#  |
#  |      - If int, then consider `min_samples_split` as the minimum number.
#  |      - If float, then `min_samples_split` is a fraction and
#  |        `ceil(min_samples_split * n_samples)` are the minimum
#  |        number of samples for each split.
#  |
#  |      .. versionchanged:: 0.18
#  |         Added float values for fractions.
#  |
#  |  min_samples_leaf : int or float, default=1
#  |      The minimum number of samples required to be at a leaf node.
#  |      A split point at any depth will only be considered if it leaves at
#  |      least ``min_samples_leaf`` training samples in each of the left and
#  |      right branches.  This may have the effect of smoothing the model,
#  |      especially in regression.
#  |
#  |      - If int, then consider `min_samples_leaf` as the minimum number.
#  |      - If float, then `min_samples_leaf` is a fraction and
#  |        `ceil(min_samples_leaf * n_samples)` are the minimum
#  |        number of samples for each node.
#  |
#  |      .. versionchanged:: 0.18
#  |         Added float values for fractions.
#  |
#  |  min_weight_fraction_leaf : float, default=0.0
#  |      The minimum weighted fraction of the sum total of weights (of all
#  |      the input samples) required to be at a leaf node. Samples have
#  |      equal weight when sample_weight is not provided.
#  |
#  |  max_features : {"auto", "sqrt", "log2"}, int or float, default="auto"
#  |      The number of features to consider when looking for the best split:
#  |
#  |      - If int, then consider `max_features` features at each split.
#  |      - If float, then `max_features` is a fraction and
#  |        `round(max_features * n_features)` features are considered at each
#  |        split.
#  |      - If "auto", then `max_features=n_features`.
#  |      - If "sqrt", then `max_features=sqrt(n_features)`.
#  |      - If "log2", then `max_features=log2(n_features)`.
#  |      - If None, then `max_features=n_features`.
#  |
#  |      Note: the search for a split does not stop until at least one
#  |      valid partition of the node samples is found, even if it requires to
#  |      effectively inspect more than ``max_features`` features.
#  |
#  |  max_leaf_nodes : int, default=None
#  |      Grow trees with ``max_leaf_nodes`` in best-first fashion.
#  |      Best nodes are defined as relative reduction in impurity.
#  |      If None then unlimited number of leaf nodes.
#  |
#  |  min_impurity_decrease : float, default=0.0
#  |      A node will be split if this split induces a decrease of the impurity
#  |      greater than or equal to this value.
#  |
#  |      The weighted impurity decrease equation is the following::
#  |
#  |          N_t / N * (impurity - N_t_R / N_t * right_impurity
#  |                              - N_t_L / N_t * left_impurity)
#  |
#  |      where ``N`` is the total number of samples, ``N_t`` is the number of
#  |      samples at the current node, ``N_t_L`` is the number of samples in the
#  |      left child, and ``N_t_R`` is the number of samples in the right child.
#  |
#  |      ``N``, ``N_t``, ``N_t_R`` and ``N_t_L`` all refer to the weighted sum,
#  |      if ``sample_weight`` is passed.
#  |
#  |      .. versionadded:: 0.19
#  |
#  |  min_impurity_split : float, default=None
#  |      Threshold for early stopping in tree growth. A node will split
#  |      if its impurity is above the threshold, otherwise it is a leaf.
#  |
#  |      .. deprecated:: 0.19
#  |         ``min_impurity_split`` has been deprecated in favor of
#  |         ``min_impurity_decrease`` in 0.19. The default value of
#  |         ``min_impurity_split`` has changed from 1e-7 to 0 in 0.23 and it
#  |         will be removed in 1.0 (renaming of 0.25).
#  |         Use ``min_impurity_decrease`` instead.
#  |
#  |  bootstrap : bool, default=True
#  |      Whether bootstrap samples are used when building trees. If False, the
#  |      whole dataset is used to build each tree.
#  |
#  |  oob_score : bool, default=False
#  |      Whether to use out-of-bag samples to estimate the generalization score.
#  |      Only available if bootstrap=True.
#  |
#  |  n_jobs : int, default=None
#  |      The number of jobs to run in parallel. :meth:`fit`, :meth:`predict`,
#  |      :meth:`decision_path` and :meth:`apply` are all parallelized over the
#  |      trees. ``None`` means 1 unless in a :obj:`joblib.parallel_backend`
#  |      context. ``-1`` means using all processors. See :term:`Glossary
#  |      <n_jobs>` for more details.
#  |
#  |  random_state : int, RandomState instance or None, default=None
#  |      Controls both the randomness of the bootstrapping of the samples used
#  |      when building trees (if ``bootstrap=True``) and the sampling of the
#  |      features to consider when looking for the best split at each node
#  |      (if ``max_features < n_features``).
#  |      See :term:`Glossary <random_state>` for details.
#  |
#  |  verbose : int, default=0
#  |      Controls the verbosity when fitting and predicting.
#  |
#  |  warm_start : bool, default=False
#  |      When set to ``True``, reuse the solution of the previous call to fit
#  |      and add more estimators to the ensemble, otherwise, just fit a whole
#  |      new forest. See :term:`the Glossary <warm_start>`.
#  |
#  |  ccp_alpha : non-negative float, default=0.0
#  |      Complexity parameter used for Minimal Cost-Complexity Pruning. The
#  |      subtree with the largest cost complexity that is smaller than
#  |      ``ccp_alpha`` will be chosen. By default, no pruning is performed. See
#  |      :ref:`minimal_cost_complexity_pruning` for details.
#  |
#  |      .. versionadded:: 0.22
#  |
#  |  max_samples : int or float, default=None
#  |      If bootstrap is True, the number of samples to draw from X
#  |      to train each base estimator.
#  |
#  |      - If None (default), then draw `X.shape[0]` samples.
#  |      - If int, then draw `max_samples` samples.
#  |      - If float, then draw `max_samples * X.shape[0]` samples. Thus,
#  |        `max_samples` should be in the interval `(0, 1)`.
#  |
#  |      .. versionadded:: 0.22
#  |
#  |  Attributes
#  |  ----------
#  |  base_estimator_ : DecisionTreeRegressor
#  |      The child estimator template used to create the collection of fitted
#  |      sub-estimators.
#  |
#  |  estimators_ : list of DecisionTreeRegressor
#  |      The collection of fitted sub-estimators.
#  |
#  |  feature_importances_ : ndarray of shape (n_features,)
#  |      The impurity-based feature importances.
#  |      The higher, the more important the feature.
#  |      The importance of a feature is computed as the (normalized)
#  |      total reduction of the criterion brought by that feature.  It is also
#  |      known as the Gini importance.
#  |
#  |      Warning: impurity-based feature importances can be misleading for
#  |      high cardinality features (many unique values). See
#  |      :func:`sklearn.inspection.permutation_importance` as an alternative.
#  |
#  |  n_features_ : int
#  |      The number of features when ``fit`` is performed.
#  |
#  |  n_outputs_ : int
#  |      The number of outputs when ``fit`` is performed.
#  |
#  |  oob_score_ : float
#  |      Score of the training dataset obtained using an out-of-bag estimate.
#  |      This attribute exists only when ``oob_score`` is True.
#  |
#  |  oob_prediction_ : ndarray of shape (n_samples,)
#  |      Prediction computed with out-of-bag estimate on the training set.
#  |      This attribute exists only when ``oob_score`` is True.
#  |
#  |  See Also
#  |  --------
#  |  DecisionTreeRegressor, ExtraTreesRegressor
#  |
#  |  Notes
#  |  -----
#  |  The default values for the parameters controlling the size of the trees
#  |  (e.g. ``max_depth``, ``min_samples_leaf``, etc.) lead to fully grown and
#  |  unpruned trees which can potentially be very large on some data sets. To
#  |  reduce memory consumption, the complexity and size of the trees should be
#  |  controlled by setting those parameter values.
#  |
#  |  The features are always randomly permuted at each split. Therefore,
#  |  the best found split may vary, even with the same training data,
#  |  ``max_features=n_features`` and ``bootstrap=False``, if the improvement
#  |  of the criterion is identical for several splits enumerated during the
#  |  search of the best split. To obtain a deterministic behaviour during
#  |  fitting, ``random_state`` has to be fixed.
#  |
#  |  The default value ``max_features="auto"`` uses ``n_features``
#  |  rather than ``n_features / 3``. The latter was originally suggested in
#  |  [1], whereas the former was more recently justified empirically in [2].
#  |
#  |  References
#  |  ----------
#  |  .. [1] L. Breiman, "Random Forests", Machine Learning, 45(1), 5-32, 2001.
#  |
#  |  .. [2] P. Geurts, D. Ernst., and L. Wehenkel, "Extremely randomized
#  |         trees", Machine Learning, 63(1), 3-42, 2006.
#  |
#  |  Examples
#  |  --------
#  |  >>> from sklearn.ensemble import RandomForestRegressor
#  |  >>> from sklearn.datasets import make_regression
#  |  >>> X, y = make_regression(n_features=4, n_informative=2,
#  |  ...                        random_state=0, shuffle=False)
#  |  >>> regr = RandomForestRegressor(max_depth=2, random_state=0)
#  |  >>> regr.fit(X, y)
#  |  RandomForestRegressor(...)
#  |  >>> print(regr.predict([[0, 0, 0, 0]]))
#  |  [-8.32987858]
#  |
#  |  Method resolution order:
#  |      RandomForestRegressor
#  |      ForestRegressor
#  |      sklearn.base.RegressorMixin
#  |      BaseForest
#  |      sklearn.base.MultiOutputMixin
#  |      sklearn.ensemble._base.BaseEnsemble
#  |      sklearn.base.MetaEstimatorMixin
#  |      sklearn.base.BaseEstimator
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, n_estimators=100, *, criterion='mse', max_depth=None, min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=None, random_state=None, verbose=0, warm_start=False, ccp_alpha=0.0, max_samples=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset()
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ForestRegressor:
#  |
#  |  predict(self, X)
#  |      Predict regression target for X.
#  |
#  |      The predicted regression target of an input sample is computed as the
#  |      mean predicted regression targets of the trees in the forest.
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix} of shape (n_samples, n_features)
#  |          The input samples. Internally, its dtype will be converted to
#  |          ``dtype=np.float32``. If a sparse matrix is provided, it will be
#  |          converted into a sparse ``csr_matrix``.
#  |
#  |      Returns
#  |      -------
#  |      y : ndarray of shape (n_samples,) or (n_samples, n_outputs)
#  |          The predicted values.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sklearn.base.RegressorMixin:
#  |
#  |  score(self, X, y, sample_weight=None)
#  |      Return the coefficient of determination :math:`R^2` of the
#  |      prediction.
#  |
#  |      The coefficient :math:`R^2` is defined as :math:`(1 - \frac{u}{v})`,
#  |      where :math:`u` is the residual sum of squares ``((y_true - y_pred)
#  |      ** 2).sum()`` and :math:`v` is the total sum of squares ``((y_true -
#  |      y_true.mean()) ** 2).sum()``. The best possible score is 1.0 and it
#  |      can be negative (because the model can be arbitrarily worse). A
#  |      constant model that always predicts the expected value of `y`,
#  |      disregarding the input features, would get a :math:`R^2` score of
#  |      0.0.
#  |
#  |      Parameters
#  |      ----------
#  |      X : array-like of shape (n_samples, n_features)
#  |          Test samples. For some estimators this may be a precomputed
#  |          kernel matrix or a list of generic objects instead with shape
#  |          ``(n_samples, n_samples_fitted)``, where ``n_samples_fitted``
#  |          is the number of samples used in the fitting for the estimator.
#  |
#  |      y : array-like of shape (n_samples,) or (n_samples, n_outputs)
#  |          True values for `X`.
#  |
#  |      sample_weight : array-like of shape (n_samples,), default=None
#  |          Sample weights.
#  |
#  |      Returns
#  |      -------
#  |      score : float
#  |          :math:`R^2` of ``self.predict(X)`` wrt. `y`.
#  |
#  |      Notes
#  |      -----
#  |      The :math:`R^2` score used when calling ``score`` on a regressor uses
#  |      ``multioutput='uniform_average'`` from version 0.23 to keep consistent
#  |      with default value of :func:`~sklearn.metrics.r2_score`.
#  |      This influences the ``score`` method of all the multioutput
#  |      regressors (except for
#  |      :class:`~sklearn.multioutput.MultiOutputRegressor`).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from sklearn.base.RegressorMixin:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseForest:
#  |
#  |  apply(self, X)
#  |      Apply trees in the forest to X, return leaf indices.
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix} of shape (n_samples, n_features)
#  |          The input samples. Internally, its dtype will be converted to
#  |          ``dtype=np.float32``. If a sparse matrix is provided, it will be
#  |          converted into a sparse ``csr_matrix``.
#  |
#  |      Returns
#  |      -------
#  |      X_leaves : ndarray of shape (n_samples, n_estimators)
#  |          For each datapoint x in X and for each tree in the forest,
#  |          return the index of the leaf x ends up in.
#  |
#  |  decision_path(self, X)
#  |      Return the decision path in the forest.
#  |
#  |      .. versionadded:: 0.18
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix} of shape (n_samples, n_features)
#  |          The input samples. Internally, its dtype will be converted to
#  |          ``dtype=np.float32``. If a sparse matrix is provided, it will be
#  |          converted into a sparse ``csr_matrix``.
#  |
#  |      Returns
#  |      -------
#  |      indicator : sparse matrix of shape (n_samples, n_nodes)
#  |          Return a node indicator matrix where non zero elements indicates
#  |          that the samples goes through the nodes. The matrix is of CSR
#  |          format.
#  |
#  |      n_nodes_ptr : ndarray of shape (n_estimators + 1,)
#  |          The columns from indicator[n_nodes_ptr[i]:n_nodes_ptr[i+1]]
#  |          gives the indicator value for the i-th estimator.
#  |
#  |  fit(self, X, y, sample_weight=None)
#  |      Build a forest of trees from the training set (X, y).
#  |
#  |      Parameters
#  |      ----------
#  |      X : {array-like, sparse matrix} of shape (n_samples, n_features)
#  |          The training input samples. Internally, its dtype will be converted
#  |          to ``dtype=np.float32``. If a sparse matrix is provided, it will be
#  |          converted into a sparse ``csc_matrix``.
#  |
#  |      y : array-like of shape (n_samples,) or (n_samples, n_outputs)
#  |          The target values (class labels in classification, real numbers in
#  |          regression).
#  |
#  |      sample_weight : array-like of shape (n_samples,), default=None
#  |          Sample weights. If None, then samples are equally weighted. Splits
#  |          that would create child nodes with net zero or negative weight are
#  |          ignored while searching for a split in each node. In the case of
#  |          classification, splits are also ignored if they would result in any
#  |          single class carrying a negative weight in either child node.
#  |
#  |      Returns
#  |      -------
#  |      self : object
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from BaseForest:
#  |
#  |  feature_importances_
#  |      The impurity-based feature importances.
#  |
#  |      The higher, the more important the feature.
#  |      The importance of a feature is computed as the (normalized)
#  |      total reduction of the criterion brought by that feature.  It is also
#  |      known as the Gini importance.
#  |
#  |      Warning: impurity-based feature importances can be misleading for
#  |      high cardinality features (many unique values). See
#  |      :func:`sklearn.inspection.permutation_importance` as an alternative.
#  |
#  |      Returns
#  |      -------
#  |      feature_importances_ : ndarray of shape (n_features,)
#  |          The values of this array sum to 1, unless all trees are single node
#  |          trees consisting of only the root node, in which case it will be an
#  |          array of zeros.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sklearn.ensemble._base.BaseEnsemble:
#  |
#  |  __getitem__(self, index)
#  |      Return the index'th estimator in the ensemble.
#  |
#  |  __iter__(self)
#  |      Return iterator over estimators in the ensemble.
#  |
#  |  __len__(self)
#  |      Return the number of estimators in the ensemble.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from sklearn.ensemble._base.BaseEnsemble:
#  |
#  |  __annotations__ = {'_required_parameters': typing.List[str]}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from sklearn.base.BaseEstimator:
#  |
#  |  __getstate__(self)
#  |
#  |  __repr__(self, N_CHAR_MAX=700)
#  |      Return repr(self).
#  |
#  |  __setstate__(self, state)
#  |
#  |  get_params(self, deep=True)
#  |      Get parameters for this estimator.
#  |
#  |      Parameters
#  |      ----------
#  |      deep : bool, default=True
#  |          If True, will return the parameters for this estimator and
#  |          contained subobjects that are estimators.
#  |
#  |      Returns
#  |      -------
#  |      params : dict
#  |          Parameter names mapped to their values.
#  |
#  |  set_params(self, **params)
#  |      Set the parameters of this estimator.
#  |
#  |      The method works on simple estimators as well as on nested objects
#  |      (such as :class:`~sklearn.pipeline.Pipeline`). The latter have
#  |      parameters of the form ``<component>__<parameter>`` so that it's
#  |      possible to update each component of a nested object.
#  |
#  |      Parameters
#  |      ----------
#  |      **params : dict
#  |          Estimator parameters.
#  |
#  |      Returns
#  |      -------
#  |      self : estimator instance
#  |          Estimator instance.

# %%
hyper_params = {'randomforestregressor__n_estimators' : [100, 200, 300 , 400 , 500, 600, 700,800, 900, 1000]}

grid = GridSearchCV(fm, hyper_params, cv=4)

# %%
grid.fit(X_train, y_train)

# %% [markdown]
# # Test de correlation

# %%
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Bathrooms', 'Bedrooms', 'Erf Size', 'Floor Size', 'Garage', 'Levies',
#        'No Transfer Duty', 'Office', 'Parking', 'Pets Allowed', 'Price per m²',
#        'Rates and Taxes', 'Reception Rooms', 'Roof', 'Security',
#        'Special Features', 'Standalone Building', 'Temperature Control',
#        'Type of Property', 'Wall', 'City', 'Price', 'Province', 'Suburbaine',
#        'Dining Rooms', 'Garden', 'Kitchens', 'Lounges'],
#       dtype='object')

# %%
(df.isna().sum() / df.shape[0]).sort_values()
# Out:
# Price                  0.000000
# No Transfer Duty       0.000000
# Office                 0.000000
# Parking                0.000000
# Pets Allowed           0.000000
# Type of Property       0.000000
# Temperature Control    0.000000
# Standalone Building    0.000000
# Special Features       0.000000
# Suburbaine             0.053947
# Province               0.053947
# City                   0.053947
# Bedrooms               0.115101
# Bathrooms              0.150785
# Kitchens               0.240513
# Rates and Taxes        0.420325
# Lounges                0.446668
# Erf Size               0.456655
# Floor Size             0.470877
# Garage                 0.529349
# Levies                 0.565841
# Dining Rooms           0.593186
# Garden                 0.632038
# Security               0.695294
# Price per m²           0.744327
# Reception Rooms        0.869739
# Wall                   0.882830
# Roof                   0.886580
# dtype: float64

# %%
corr_col = ["Bathrooms"]

# %%
plt.figure(figsize=(12,10))
sns.pairplot(df[corr_col])
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dataExp = pd.read_csv('cleaned_data.csv')

# %%
corr_col = ["Price per m²","Price"]
sns.pairplot(df[corr_col])

# %%
sns.relplot(x="Price per m²", y="Price", data=df);

# %%
# sns.relplot(x="Type of Property", y="Price", data=df);
sns.heatmap(pd.crosstab(df['Price'], df["Type of Property"]), annot=True, fmt='d')
# Out:
# <AxesSubplot:xlabel='Type of Property', ylabel='Price'>
# Error in callback <function flush_figures at 0x7f70c28b79d0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/.local/lib/python3.9/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     118         # ignore the tracking, just draw and close all figures
#     119         try:
# --> 120             return show(True)
#     121         except Exception as e:
#     122             # safely show traceback if in IPython, else raise
#
# ~/.local/lib/python3.9/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      38     try:
#      39         for figure_manager in Gcf.get_all_fig_managers():
# ---> 40             display(
#      41                 figure_manager.canvas.figure,
#      42                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/lib/python3/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/lib/python3/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/lib/python3/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/lib/python3/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/lib/python3/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/.local/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2232             if bbox_inches:
#    2233                 if bbox_inches == "tight":
# -> 2234                     bbox_inches = self.figure.get_tightbbox(
#    2235                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2236                     if pad_inches is None:
#
# ~/.local/lib/python3.9/site-packages/matplotlib/figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1659                 bb = [self.bbox]
#    1660
# -> 1661         _bbox = Bbox.union(bb)
#    1662
#    1663         bbox_inches = TransformedBbox(_bbox, Affine2D().scale(1 / self.dpi))
#
# ~/.local/lib/python3.9/site-packages/matplotlib/transforms.py in union(bboxes)
#     678         if not len(bboxes):
#     679             raise ValueError("'bboxes' cannot be empty")
# --> 680         x0 = np.min([bbox.xmin for bbox in bboxes])
#     681         x1 = np.max([bbox.xmax for bbox in bboxes])
#     682         y0 = np.min([bbox.ymin for bbox in bboxes])
#
# ~/.local/lib/python3.9/site-packages/matplotlib/transforms.py in <listcomp>(.0)
#     678         if not len(bboxes):
#     679             raise ValueError("'bboxes' cannot be empty")
# --> 680         x0 = np.min([bbox.xmin for bbox in bboxes])
#     681         x1 = np.max([bbox.xmax for bbox in bboxes])
#     682         y0 = np.min([bbox.ymin for bbox in bboxes])
#
# ~/.local/lib/python3.9/site-packages/matplotlib/transforms.py in xmin(self)
#     327     def xmin(self):
#     328         """The left edge of the bounding box."""
# --> 329         return np.min(self.get_points()[:, 0])
#     330
#     331     @property
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# /usr/lib/python3/dist-packages/numpy/core/fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2828     6
#    2829     """
# -> 2830     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2831                           keepdims=keepdims, initial=initial, where=where)
#    2832
#
# /usr/lib/python3/dist-packages/numpy/core/fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      69
#      70 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 71     passkwargs = {k: v for k, v in kwargs.items()
#      72                   if v is not np._NoValue}
#      73
#
# KeyboardInterrupt:

# %%
sns.relplot(x="Special Features", y="Price", data=df);

# %%
sns.relplot(x="Bathrooms", y="Price", data=df);

# %%
sns.relplot(x="Bedrooms", y="Price", data=df);

# %%
df["Bedrooms/Bathrooms"]=df["Bedrooms"]/df["Bathrooms"]

# %%
sns.relplot(x="Bedrooms/Bathrooms", y="Price", data=df);

# %%
df["Bathrooms/Bedrooms"]= df["Bathrooms"] / df["Bedrooms"]

# %%
sns.relplot(x="Bathrooms/Bedrooms", y="Price", data=df);

# %%
# XGB Regressor
print("Linear Regression")
evaluation(XGBReg)
# Out:
# Linear Regression
#        Bathrooms  Bedrooms   Erf Size  Floor Size  Garage  Levies  \
# 16400        3.0       3.0  7150000.0         NaN     NaN     NaN
# 7519         5.5       5.0     2067.0         NaN     3.0     NaN
# 19698        2.0       3.0        NaN       222.0     NaN     NaN
# 30210        2.0       5.0    17800.0         NaN     1.0     NaN
# 220          1.0       3.0      300.0       133.0     NaN     NaN
# ...          ...       ...        ...         ...     ...     ...
# 13123        1.0       NaN        NaN        48.0     NaN  1913.0
# 19648        1.0       2.0    43089.0        83.0     NaN     NaN
# 9845         2.5       3.0        NaN         NaN     1.0     NaN
# 10799        3.0       5.0      991.0         NaN     NaN  1000.0
# 2732         1.0       2.0        NaN        74.0     NaN  2148.0
#
#        No Transfer Duty  Office  Parking  Pets Allowed  ...  \
# 16400                 0       0      0.0             1  ...
# 7519                  0       0     10.0             1  ...
# 19698                 0       0      0.0             0  ...
# 30210                 0       0      1.0             0  ...
# 220                   0       0      0.0             0  ...
# ...                 ...     ...      ...           ...  ...
# 13123                 0       0      0.0             0  ...
# 19648                 0       0      2.0             0  ...
# 9845                  0       0      0.0             0  ...
# 10799                 0       1      0.0             1  ...
# 2732                  0       0      0.0             0  ...
#
#        Temperature Control  Type of Property     Wall         City  \
# 16400                    0         Townhouse      NaN      witbank
# 7519                     0             House      NaN      sandton
# 19698                    0             House      NaN    cape-town
# 30210                    0             House      NaN  randfontein
# 220                      0             House      NaN   soshanguve
# ...                    ...               ...      ...          ...
# 13123                    0  Apartment / Flat  Plaster     hermanus
# 19648                    0  Apartment / Flat      NaN    lephalale
# 9845                     0  Apartment / Flat      NaN   middelburg
# 10799                    0             House      NaN       akasia
# 2732                     0  Apartment / Flat      NaN      sandton
#
#            Province          Suburbaine  Dining Rooms  Garden Kitchens Lounges
# 16400    mpumalanga         reyno-ridge           NaN     NaN      1.0     1.0
# 7519        gauteng              atholl           1.0     1.0      1.0     1.0
# 19698  western-cape         observatory           1.0     NaN      1.0     1.0
# 30210       gauteng           bootha-ah           1.0     1.0      1.0     NaN
# 220         gauteng        soshanguve-l           NaN     NaN      1.0     1.0
# ...             ...                 ...           ...     ...      ...     ...
# 13123  western-cape           westcliff           NaN     1.0      1.0     NaN
# 19648       limpopo          onverwacht           NaN     NaN      1.0     1.0
# 9845     mpumalanga  middelburg-central           NaN     NaN      NaN     NaN
# 10799       gauteng        the-orchards           NaN     1.0      NaN     NaN
# 2732        gauteng            paulshof           NaN     NaN      NaN     NaN
#
# [24750 rows x 27 columns]
# Normal Mean Error:  719702.70807157
# Root Mean Squared Error:  0.4536539915282454
# <ipython-input-408-2ea666a4f6a0>:2: RuntimeWarning: invalid value encountered in log
#   error = np.square(np.subtract(np.log(y_test),np.log(y_pred))).mean()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-413-1391cc99916f> in <module>
#       1 # XGB Regressor
#       2 print("Linear Regression")
# ----> 3 evaluation(XGBReg)
#
# <ipython-input-411-82b3d4234bcc> in evaluation(model)
#       8     print('Root Mean Squared Error: ',RMSE(y_test, y_pred))
#       9
# ---> 10     N, train_score, val_score = learning_curve(model, X_train, y_train,
#      11                                               cv=4,train_sizes=np.linspace(0.1, 1, 10))
#      12
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/.local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in learning_curve(estimator, X, y, groups, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, verbose, shuffle, random_state, error_score, return_times, fit_params)
#    1410                 train_test_proportions.append((train[:n_train_samples], test))
#    1411
# -> 1412         results = parallel(delayed(_fit_and_score)(
#    1413             clone(estimator), X, y, scorer, train, test, verbose,
#    1414             parameters=None, fit_params=fit_params, return_train_score=True,
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~/.local/lib/python3.9/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/.local/lib/python3.9/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/.local/lib/python3.9/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~/.local/lib/python3.9/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     596             estimator.fit(X_train, **fit_params)
#     597         else:
# --> 598             estimator.fit(X_train, y_train, **fit_params)
#     599
#     600     except Exception as e:
#
# ~/.local/lib/python3.9/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# ~/.local/lib/python3.9/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     434         for k, arg in zip(sig.parameters, args):
#     435             kwargs[k] = arg
# --> 436         return f(**kwargs)
#     437
#     438     return inner_f
#
# ~/.local/lib/python3.9/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     734
#     735         model, feval, params = self._configure_fit(xgb_model, eval_metric, params)
# --> 736         self._Booster = train(
#     737             params,
#     738             train_dmatrix,
#
# ~/.local/lib/python3.9/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     187     Booster : a trained booster model
#     188     """
# --> 189     bst = _train_internal(params, dtrain,
#     190                           num_boost_round=num_boost_round,
#     191                           evals=evals,
#
# ~/.local/lib/python3.9/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79         if callbacks.before_iteration(bst, i, dtrain, evals):
#      80             break
# ---> 81         bst.update(dtrain, i, obj)
#      82         if callbacks.after_iteration(bst, i, dtrain, evals):
#      83             break
#
# ~/.local/lib/python3.9/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1497
#    1498         if fobj is None:
# -> 1499             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1500                                                     ctypes.c_int(iteration),
#    1501                                                     dtrain.handle))
#
# KeyboardInterrupt:
